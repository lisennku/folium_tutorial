# %% [markdown]
# # 0A. 导入包

# %%
import folium
from folium import plugins
import json
import pandas as pd
import vincent
vincent.core.initialize_notebook()
import altair
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %% [markdown]
# # 0B Reference Link:
# - [folium document](https://python-visualization.github.io/folium/modules.html)
# - [folium official demo](https://nbviewer.org/github/python-visualization/folium/blob/main/examples/Popups.ipynb)
# - [vincent document](https://vincent.readthedocs.io/en/latest/quickstart.html#axis-labels)
# - [altair document](https://altair-viz.github.io/index.html)
# - [Folium — 可能是 Python 最强的绘制地图神器](https://pythondict.com/python-paintings/folium/)
# - [同济子豪兄 folium 交互式地图可视化demo](https://github.com/TommyZihao/folium_tutorials)

# %% [markdown]
# # 1. 函数与类分析

# %% [markdown]
# ## 1.1 \_\_init__.py文件中函数分析

# %% [markdown]
# \_\_init__.py文件中定义了__all__变量，使得该变量内的所有方法可以通过`folium.`直接访问，但这些函数真实的类定义是在不同模块中：
# - `folium.folium`:
#     - `Map`          用于创建基础地图
# - `folium.map`:
#     - `FeatureGroup`     用于创建一个集合，该集合可以看做一个单独的图层，可以向该图层内添加对象，并使用LayerControl控制是否显示
#     - `FitBounds`
#     - `Icon`             图标类，使用font-awesome或boostrap图标
#     - `LayerControl`     用于在地图上添加一个图层显示控制按钮
#     - `Marker`           标记类，用于在地图上添加一个标记
#     - `Popup`            弹出类，用于设置某个对象的`popup`参数
#     - `Tooltip`          提示类，用于设置某个对象的`tooltip`参数
# - `folium.vector_layers`
#     - `Circle`           用于在地图上绘制一个圆形，其半径会随着地图缩放而改变
#     - `CircleMarker`     用于在地图上绘制一个固定圆形，其半径不随地图缩放而改变
#     - `PolyLine`         用于绘制线条
#     - `Polygon`          用于绘制多边形
#     - `Rectangle`        用于绘制矩形，其矩形是根据给定的经纬度点所能围成的最大矩形而定，不一定所有给定的点都在矩形边上
# - `folium.raster_layers`
#     - `TileLayer`        在地图上添加一个瓦片图层
#     - `WmsTileLayer`     创建一个网络地图服务层
# - `folium.features`
#     - `Choropleth`       分级统计图
#     - `ClickForMarker`   鼠标在地图上点击，添加一个标记
#     - `ColorLine`        用于绘制颜色线条
#     - `CustomIcon`       使用图片自定义图标
#     - `DivIcon`
#     - `GeoJson`          读取GeoJson格式文件并绘制在地图上
#     - `GeoJsonTooltip`   根据GeoJson中每个层级的属性进行提示内容设置
#     - `GeoJsonPopup`     根据GeoJson中每个层级的属性进行弹出内容设置
#     - `LatLngPopup`      点击地图并显示对应的经纬度
#     - `RegularPolygonMarker`
#     - `TopoJson`
#     - `Vega`             创建一个Vega图表元素
#     - `VegaLite`         创建一个VegaLite图表元素

# %% [markdown]
# ## 1.2 plugins类

# %% [markdown]
# `plugins`需要从`folium`中导入后使用
# > ```python
#     from folium import plugins

# %% [markdown]
# `plugins.`
# - `AntPath`           绘制蚂蚁路线，从开头到结尾显示动态路线
# - `BeautifyIcon`      使用美化的font-awesome图标，也可使用数字作为图标
# - `BoatMarker`        绘制船型图标以及风向图标
# - `Draw`              添加绘图工具
# - `DualMap`           双幅地图
# - `FastMarkerCluster` 快速批量添加标记
# - `FloatImage`        浮动图片
# - `FullScreen`        全屏
# - `GeoCoder`          搜索
# - `HeatMap`           热力图
# - `HeatMapWithTime`   时序热力图
# - `LocateControl`     定位当前位置
# - `MarkerCluster`     批量添加标记
# - `MeasureControl`    度量工具
# - `MiniMap`           迷你地图
# - `MousePosition`     鼠标移动并显示对应经纬度
# - `ScrollZoomToggler` 停止/开始缩放按钮
# - `Search`            搜索图层内容
# - `SemiCircle`        扇形
# - `Terminator`        晨昏线

# %% [markdown]
# # 2. 创建基础地图

# %% [markdown]
# ## 2.1 函数参数：
# ```python
# folium.Map(
#     location,  地图视角的中心，元组或者列表，[latitude, longitude]
#     width='100%',  像素整数值或者百分比字符串值，控制限制的地图大小
#     height='100%',
#     left='0%',
#     right='0%',
#     position='relative',
#     tiles='OpenStreetMap',    瓦片，可以是内置的，也可以自定义瓦片url，但是如果是自定义的，必须指定attr属性
#         - 内置：
#             - "OpenStreetMap"
#             - "Mapbox Bright" (Limited levels of zoom for free tiles)
#             - "Mapbox Control Room" (Limited levels of zoom for free tiles)
#             - "Stamen" (Terrain, Toner, and Watercolor)
#             - "Cloudmade" (Must pass API key)
#             - "Mapbox" (Must pass API key)
#             - "CartoDB" (positron and dark_matter)
#         - 自定义：
#             - 高德：'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7'
#     attr=None,
#         -  高德：'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7'
#         - '高德-常规图'
#     min_zoom=0,               设置允许的缩小的最小倍数
#     max_zoom=18,              设置允许的放大的最大倍数
#     zoom_start=10,            开始时放大的倍数
#     min_lat=- 90,
#     max_lat=90,
#     min_lon=- 180,
#     max_lon=180,
#     max_bounds=False,
#     crs='EPSG3857',           投影坐标系标识
#     control_scale=False,      是否在地图上显示比例尺
#     prefer_canvas=False,
#     no_touch=False,
#     disable_3d=False,
#     png_enabled=False,
#     zoom_control=True,
#     **kwargs
# )
# ```

# %% [markdown]
# ## 2.2 主要参数

# %% [markdown]
# - `location`:
#     - 地图视角的中心经纬度，[lat, lng]，列表形式，如果为None，则以[0, 0]形式为中心
#     - 经纬度要以所使用的tiles为基础，否则会出现位置对应不上的问题

# %% [markdown]
# - tiles:
#     - 用于设置地图的瓦片信息，内置了许多国外的地图提供商，但是国内使用一般不建议
#     - 自定义， 如果使用了自定义，则必须对`attr`参数传参
#         - 可以使用高德或其他国内地图提供商
#             - 高德：http://wprd0{1-4}.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=1
#                 - style：设置影像和路网，style=6为卫星图，style=7为街道图，style=8为标注图
#             - 腾讯：http://rt1.map.gtimg.com/realtimerender?z={z}&x={x}&y={y}&type=vector&style=0
#                 - 使用时需设置参数`tms=True`

# %% [markdown]
# 地球上同一个地理位置的经纬度，在不同的坐标系中，会有少量偏移，国内目前常见的坐标系主要分为三种：
# - 地球坐标系——WGS84：常见于GPS设备，Google地图等国际标准的坐标体系。
# - 火星坐标系——GCJ-02：中国国内使用的被强制加密后的坐标体系，高德坐标就属于该种坐标体系。
# - 百度坐标系——BD-09：百度地图所使用的坐标体系，是在火星坐标系的基础上又进行了一次加密处理

# %% [markdown]
# 同一个位置，不同坐标系下的坐标：通过下边两个图的对比可知，要确定经纬度从何种tiles获取，并使用相对应的tiles
# - 位置：
#     - 四川省第四人民医院
# -经纬度：
#     - 高德：
#         - [30.653138, 104.076315]
#     - OpenStreetMap：
#         - [30.6552, 104.0737]

# %% [markdown]
# ### 2.2.1 OpenStreetMap tiles

# %%
# 使用默认tiles
map1 = folium.Map(
    location=[30.6611, 104.0634],
    min_zoom=15, 
    zoom_start=15
)
folium.Marker(  # 高德经纬度
    location=[30.653138, 104.076315],
).add_to(map1)
folium.Marker(  # OpenStreetMap经纬度
    location=[30.6552, 104.0737],
).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3b0592dbe70c5543b3609987d86b939 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3b0592dbe70c5543b3609987d86b939&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3b0592dbe70c5543b3609987d86b939 = L.map(
#                 &quot;map_b3b0592dbe70c5543b3609987d86b939&quot;,
#                 {
#                     center: [30.6611, 104.0634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec9a48834255f2b6c16a07a8f5bdad57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 15, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3b0592dbe70c5543b3609987d86b939);
#
#
#             var marker_0347ded733b0ca03b76fd40d10f540d8 = L.marker(
#                 [30.653138, 104.076315],
#                 {}
#             ).addTo(map_b3b0592dbe70c5543b3609987d86b939);
#
#
#             var marker_c18b6c7d81e45446f60528077a6d1433 = L.marker(
#                 [30.6552, 104.0737],
#                 {}
#             ).addTo(map_b3b0592dbe70c5543b3609987d86b939);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.2.2 高德tiles

# %%
# 使用高德tiles
map2 = folium.Map(
    tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6611, 104.0634],
    min_zoom=15, 
    zoom_start=15
)
folium.Marker(  # 高德经纬度
    location=[30.653138, 104.076315],
).add_to(map2)
folium.Marker(  # OpenStreetMap经纬度经纬度
    location=[30.6552, 104.0737],
).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f428dee24ad7334ec643cb3ef10749df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f428dee24ad7334ec643cb3ef10749df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f428dee24ad7334ec643cb3ef10749df = L.map(
#                 &quot;map_f428dee24ad7334ec643cb3ef10749df&quot;,
#                 {
#                     center: [30.6611, 104.0634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fbdf3173ebb90e408127b6fc394e9e5 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 15, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f428dee24ad7334ec643cb3ef10749df);
#
#
#             var marker_b2b54f6d14163ff58e6fd358628e620a = L.marker(
#                 [30.653138, 104.076315],
#                 {}
#             ).addTo(map_f428dee24ad7334ec643cb3ef10749df);
#
#
#             var marker_1c8480d2e720bab093d9e1e248193102 = L.marker(
#                 [30.6552, 104.0737],
#                 {}
#             ).addTo(map_f428dee24ad7334ec643cb3ef10749df);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 3. map下的类

# %% [markdown]
# ## 3.1 FeatureGroup
# 该类主要用来作为一个单独图层，可以向该单独图层中添加对象，并结合`LayerControl`进行图层选择设置
# 其中参数`overlay`一般设置为`True`，也即作为一个叠加图层而非基础图层，否则会在选择中覆盖`Map`中的`tiles`参数

# %% [markdown]
# ```python
# folium.FeatureGroup(
#     name          体现在LayerControl中的名字
#     overlay       默认为True，控制图层是叠加overlay还是基础base，体现在LayerControl中就是图层是复选还是单选
#     control       默认为True，控制是否添加到LayerControl中
#     show          默认为True，控制是否在打开时就渲染，只针对overlay生效
#     )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=15, 
    zoom_start=15
)
g1 = folium.FeatureGroup(name='g1', overlay=False)
g2 = folium.FeatureGroup(name='g2', overlay=True)

folium.Marker(
    location=[30.6570, 104.0679]
).add_to(g1)

folium.Marker(
    location=[30.6568, 104.0686]
).add_to(g2)

map.add_child(g1)
map.add_child(g2)

map.add_child(
    folium.Marker(
        location=[30.657453, 104.065751]
    )
)
map.add_child(
    folium.LayerControl()
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46da86f2da8e58673a330bb1e052fd8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46da86f2da8e58673a330bb1e052fd8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46da86f2da8e58673a330bb1e052fd8d = L.map(
#                 &quot;map_46da86f2da8e58673a330bb1e052fd8d&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df61c4bc8672bbc623239f7072aadfa = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 15, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46da86f2da8e58673a330bb1e052fd8d);
#
#
#             var feature_group_f935ff90cf1b5faee1a901e0257c609c = L.featureGroup(
#                 {}
#             ).addTo(map_46da86f2da8e58673a330bb1e052fd8d);
#
#
#             var marker_8ef54f549ba787d77cbeee8d7a990dde = L.marker(
#                 [30.657, 104.0679],
#                 {}
#             ).addTo(feature_group_f935ff90cf1b5faee1a901e0257c609c);
#
#
#             var feature_group_94bfd76eeccaec03a4ddd2d12d6f8d54 = L.featureGroup(
#                 {}
#             ).addTo(map_46da86f2da8e58673a330bb1e052fd8d);
#
#
#             var marker_33f582eb10d4949bd39d200a631d5f15 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(feature_group_94bfd76eeccaec03a4ddd2d12d6f8d54);
#
#
#             var marker_270724a72cdab98d101856eeabebb55b = L.marker(
#                 [30.657453, 104.065751],
#                 {}
#             ).addTo(map_46da86f2da8e58673a330bb1e052fd8d);
#
#
#             var layer_control_294bb03e921dc95c789dfb9b8b0221d4 = {
#                 base_layers : {
#                     &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot; : tile_layer_9df61c4bc8672bbc623239f7072aadfa,
#                     &quot;g1&quot; : feature_group_f935ff90cf1b5faee1a901e0257c609c,
#                 },
#                 overlays :  {
#                     &quot;g2&quot; : feature_group_94bfd76eeccaec03a4ddd2d12d6f8d54,
#                 },
#             };
#             L.control.layers(
#                 layer_control_294bb03e921dc95c789dfb9b8b0221d4.base_layers,
#                 layer_control_294bb03e921dc95c789dfb9b8b0221d4.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_46da86f2da8e58673a330bb1e052fd8d);
#             feature_group_f935ff90cf1b5faee1a901e0257c609c.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3.2 FitBounds
# 该类主要用于调整地图以包含具有最大缩放级别的边界框， 效果同`m.fit_bounds`

# %% [markdown]
# ```python
# FitBounds(
#     bounds,    [lat, lng]组成的列表
#     padding_top_left=None,
#     padding_bottom_right=None,
#     padding=None,
#     max_zoom=None
# )
# ```

# %%
map = map2 = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=15, 
    zoom_start=15
)
map.add_child(
    folium.Marker(
        location=[30.657453, 104.065751]
    )
)
map.add_child(
    folium.Marker(
        location=[30.6570, 104.0679]
    )
)
map.add_child(
    folium.Marker(
        location=[30.6568, 104.0686]
    )
)

map.fit_bounds(bounds=[[30.6570, 104.0679], [30.6568, 104.0686], [30.657453, 104.065751]])

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7884034c5339330a8915a35939778187 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7884034c5339330a8915a35939778187&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7884034c5339330a8915a35939778187 = L.map(
#                 &quot;map_7884034c5339330a8915a35939778187&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8872e87199b45cfb0cd675210edb60bb = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 15, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7884034c5339330a8915a35939778187);
#
#
#             var marker_6e18ae12feecabef2a875efc3efe659e = L.marker(
#                 [30.657453, 104.065751],
#                 {}
#             ).addTo(map_7884034c5339330a8915a35939778187);
#
#
#             var marker_e9ad802e3dcd345b36ca2d999e4b09f7 = L.marker(
#                 [30.657, 104.0679],
#                 {}
#             ).addTo(map_7884034c5339330a8915a35939778187);
#
#
#             var marker_2ac9aa07edcd05906dc215fae6bac9b1 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(map_7884034c5339330a8915a35939778187);
#
#
#             map_7884034c5339330a8915a35939778187.fitBounds(
#                 [[30.657, 104.0679], [30.6568, 104.0686], [30.657453, 104.065751]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3.3 Icon
# 标记上的图标，使用boostrap3或font-awesome图标，使用font-awesome图标时`prefix`参数要设置为'fa'
# > boostrap3图标网址： https://getbootstrap.com/docs/3.3/components/
# > font-awesome图标网址： https://fontawesome.com/v4/icons/

# %% [markdown]
# ```python
# folium.Icon(
#     color ,     标记的颜色字符串，默认是'blue', 颜色字符串应在以下范围，否则会触发警告:
#                 [
#                 'red', 'blue', 'green', 'purple', 'orange', 'darkred','lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#                 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen','gray', 'black', 'lightgray'
#                 ]
#     icon_color , 图标的颜色字符串，默认是white, 颜色字符串可以参考上面的范围，也可以是html颜色编码
#     icon,        图标 默认是'info-sign', 图标的字符串名字, 根据所选图标的不同，可能需要设置prefix参数
#     angle ,      整数，默认为0, Icon旋转的角度
#     prefix ,     str, default 'glyphicon'
#                     对于boostrap3的图标，应为'glyphicon'，boostrap图标可参照：https://getbootstrap.com/docs/3.3/components/
#                     对于font-awesome的图标，应为'fa'，font-awesome图标可参照：https://fontawesome.com/v4/icons/
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=10, 
    zoom_start=15
)


# [[30.6570, 104.0679], [30.6568, 104.0686], [30.657453, 104.065751]]


folium.Marker(
    location=[30.6570, 104.0679],
    icon=folium.Icon(color='orange', icon_color='darkgreen', icon='truck', prefix='fa')
).add_to(map)

folium.Marker(
    location=[30.6568, 104.0686],
    icon=folium.Icon(color='beige', icon_color='lightblue', icon='plus', angle=90)
).add_to(map)

folium.Marker(
    location=[30.657453, 104.065751],
    icon=folium.Icon(color='cadetblue', icon_color='red', icon='car', prefix='fa', angle=45)
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59ada6297ea90868cdc989e943012929 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59ada6297ea90868cdc989e943012929&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59ada6297ea90868cdc989e943012929 = L.map(
#                 &quot;map_59ada6297ea90868cdc989e943012929&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaa976860e711fdf73e5dfd5d541a2b3 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59ada6297ea90868cdc989e943012929);
#
#
#             var marker_293a90cc3a6601a08c4d46df31ccb3df = L.marker(
#                 [30.657, 104.0679],
#                 {}
#             ).addTo(map_59ada6297ea90868cdc989e943012929);
#
#
#             var icon_a3f715fe633462944671fc90ff758fe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;darkgreen&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_293a90cc3a6601a08c4d46df31ccb3df.setIcon(icon_a3f715fe633462944671fc90ff758fe3);
#
#
#             var marker_23652070a020e2fd0ddadd7ba089b614 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(map_59ada6297ea90868cdc989e943012929);
#
#
#             var icon_7963576c74c48a7bfc5356a52f59a1c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-90&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;lightblue&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_23652070a020e2fd0ddadd7ba089b614.setIcon(icon_7963576c74c48a7bfc5356a52f59a1c2);
#
#
#             var marker_8ee4b1b5c7578572ccee98c904838867 = L.marker(
#                 [30.657453, 104.065751],
#                 {}
#             ).addTo(map_59ada6297ea90868cdc989e943012929);
#
#
#             var icon_1cad7209581c32a9b0e0d5071d15a8ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-45&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8ee4b1b5c7578572ccee98c904838867.setIcon(icon_1cad7209581c32a9b0e0d5071d15a8ca);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.default_js
# Out:
# [('leaflet', 'https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js'),
#  ('jquery', 'https://code.jquery.com/jquery-1.12.4.min.js'),
#  ('bootstrap',
#   'https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js'),
#  ('awesome_markers',
#   'https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js')]

# %% [markdown]
# ## 3.4 LayerControl
# 用来显示控制图层的按钮

# %% [markdown]
# ```python
# folium.LayerControl(
#     position   位置字符串，默认是topright，'topleft', 'topright', 'bottomleft', 'bottomright'
#     collapsed  是否折叠，默认为True
#     autoZIndex 顺序，默认为True
# )
#
# ```

# %% [markdown]
# ## 3.5 Marker
# 地图标记
# popup的宽度比较窄，多个汉字会长条状垂直显示，可以使用folium.Popup传参更改宽度

# %% [markdown]
# ```python
# folium.Marker(
#     location=None,   标记点 元组或者列表，[latitude, longitude]
#     popup=None,      点击标记点时弹出的内容
#         - 字符串
#         - html字符串  实际是folium.Popup实例化
#         - folium.Popup对象
#     tooltip=None,    鼠标移动到标记点时弹出的提示
#         - 字符串
#         - folium.Tooltip对象
#     icon=None,       图标
#         - folium.Icon对象
#     draggable=False  标记点是否可拖拽
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=10, 
    zoom_start=15
)


[[30.6570, 104.0679], [30.6568, 104.0686], [30.657453, 104.065751]]


folium.Marker(
    location=[30.6570, 104.0679],
    icon=folium.Icon(color='orange', icon_color='darkgreen', icon='truck', prefix='fa'),
    popup='marker 1',
    tooltip='marker 1',
    draggable=True
).add_to(map)

folium.Marker(
    location=[30.6568, 104.0686],
    icon=folium.Icon(color='beige', icon_color='lightblue', icon='bookmark', angle=90),
    popup='marker 2',
    tooltip='marker 2',
    draggable=False
).add_to(map)

folium.Marker(
    location=[30.657453, 104.065751],
    icon=folium.Icon(color='cadetblue', icon_color='red', icon='android', prefix='fa', angle=45),
    popup='marker 3',
    tooltip='marker 3',
    draggable=True
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca86ba1681f456e21bd1839ff985bce9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca86ba1681f456e21bd1839ff985bce9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca86ba1681f456e21bd1839ff985bce9 = L.map(
#                 &quot;map_ca86ba1681f456e21bd1839ff985bce9&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65c2077a794acdab31ab1f93b9e71bf7 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca86ba1681f456e21bd1839ff985bce9);
#
#
#             var marker_8c740351fa054ab27274febda29bb415 = L.marker(
#                 [30.657, 104.0679],
#                 {&quot;autoPan&quot;: true, &quot;draggable&quot;: true}
#             ).addTo(map_ca86ba1681f456e21bd1839ff985bce9);
#
#
#             var icon_2059494e80fc0679b1c00055eb70c7c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;darkgreen&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8c740351fa054ab27274febda29bb415.setIcon(icon_2059494e80fc0679b1c00055eb70c7c8);
#
#
#         var popup_1b16fed63ecad55187bf6c9879794fa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ceedef6607862378d77a7e0a470c211f = $(`&lt;div id=&quot;html_ceedef6607862378d77a7e0a470c211f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;marker 1&lt;/div&gt;`)[0];
#                 popup_1b16fed63ecad55187bf6c9879794fa8.setContent(html_ceedef6607862378d77a7e0a470c211f);
#
#
#
#         marker_8c740351fa054ab27274febda29bb415.bindPopup(popup_1b16fed63ecad55187bf6c9879794fa8)
#         ;
#
#
#
#
#             marker_8c740351fa054ab27274febda29bb415.bindTooltip(
#                 `&lt;div&gt;
#                      marker 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5baf3d19ed960e075f87484de11d90d1 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(map_ca86ba1681f456e21bd1839ff985bce9);
#
#
#             var icon_1c24790cf87e6442a9d4c15c33f1a231 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-90&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;lightblue&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5baf3d19ed960e075f87484de11d90d1.setIcon(icon_1c24790cf87e6442a9d4c15c33f1a231);
#
#
#         var popup_9838ce6ebc96023c0ca9a870b6ad5460 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23629354133d062abf795647a7a4b742 = $(`&lt;div id=&quot;html_23629354133d062abf795647a7a4b742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;marker 2&lt;/div&gt;`)[0];
#                 popup_9838ce6ebc96023c0ca9a870b6ad5460.setContent(html_23629354133d062abf795647a7a4b742);
#
#
#
#         marker_5baf3d19ed960e075f87484de11d90d1.bindPopup(popup_9838ce6ebc96023c0ca9a870b6ad5460)
#         ;
#
#
#
#
#             marker_5baf3d19ed960e075f87484de11d90d1.bindTooltip(
#                 `&lt;div&gt;
#                      marker 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3a34455223490534471164a76cf8bc7c = L.marker(
#                 [30.657453, 104.065751],
#                 {&quot;autoPan&quot;: true, &quot;draggable&quot;: true}
#             ).addTo(map_ca86ba1681f456e21bd1839ff985bce9);
#
#
#             var icon_ab551d72fdac22c8a7dfa498471563f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-45&quot;, &quot;icon&quot;: &quot;android&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a34455223490534471164a76cf8bc7c.setIcon(icon_ab551d72fdac22c8a7dfa498471563f0);
#
#
#         var popup_2c5542c972064ebe514fc2439883378c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f882a0c3111aa70fa11353aa53cf4632 = $(`&lt;div id=&quot;html_f882a0c3111aa70fa11353aa53cf4632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;marker 3&lt;/div&gt;`)[0];
#                 popup_2c5542c972064ebe514fc2439883378c.setContent(html_f882a0c3111aa70fa11353aa53cf4632);
#
#
#
#         marker_3a34455223490534471164a76cf8bc7c.bindPopup(popup_2c5542c972064ebe514fc2439883378c)
#         ;
#
#
#
#
#             marker_3a34455223490534471164a76cf8bc7c.bindToo

# %% [markdown]
# ## 3.6 Popup
# 用来设置弹出内容

# %% [markdown]
# ```python
# folium.Popup(
#     html: 弹出的内容，字符串或者branca.element对象
#     parse_html: 默认False，当弹出的内容是模板时，设置为True，表示需要先渲染
#     max_width: 弹出界面的最大值，表示像素的整数或者表示百分比的字符串，默认为'100%'
#     show: 默认为False，是否在html文件打开时即刻渲染
#     sticky: 默认为False， 是否通过点击地图或者其他popup来关闭当前显示的popup
#     lazy: 默认为False，是否在点击前就加载popup的内容
# )
#
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=10, 
    zoom_start=15
)


[[30.6570, 104.0679], [30.6568, 104.0686], [30.657453, 104.065751]]

html = """
    <h1> This is a big popup</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """

folium.Marker(
    location=[30.6570, 104.0679],
    icon=folium.Icon(color='orange', icon_color='darkgreen', icon='truck', prefix='fa'),
    popup=folium.Popup(html=html, max_width=1000),
    tooltip='html string',
    draggable=True
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9555e04801a7a585db58c526d1df9274 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9555e04801a7a585db58c526d1df9274&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9555e04801a7a585db58c526d1df9274 = L.map(
#                 &quot;map_9555e04801a7a585db58c526d1df9274&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05edebce5dbdaed9bdf8bd01e55b6cbf = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9555e04801a7a585db58c526d1df9274);
#
#
#             var marker_807f6fbbaa91b6c1b1553298f3a39be8 = L.marker(
#                 [30.657, 104.0679],
#                 {&quot;autoPan&quot;: true, &quot;draggable&quot;: true}
#             ).addTo(map_9555e04801a7a585db58c526d1df9274);
#
#
#             var icon_874c8bdb8361f1372d759649c2819ee2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;darkgreen&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_807f6fbbaa91b6c1b1553298f3a39be8.setIcon(icon_874c8bdb8361f1372d759649c2819ee2);
#
#
#         var popup_12a22fe9f89ef8ce2f5282f4f0012e96 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_08383a1396460b609a9d3c6aafd1f14e = $(`&lt;div id=&quot;html_08383a1396460b609a9d3c6aafd1f14e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h1&gt; This is a big popup&lt;/h1&gt;&lt;br&gt;     With a few lines of code...     &lt;p&gt;     &lt;code&gt;         from numpy import *&lt;br&gt;         exp(-2*pi)     &lt;/code&gt;     &lt;/p&gt;     &lt;/div&gt;`)[0];
#                 popup_12a22fe9f89ef8ce2f5282f4f0012e96.setContent(html_08383a1396460b609a9d3c6aafd1f14e);
#
#
#
#         marker_807f6fbbaa91b6c1b1553298f3a39be8.bindPopup(popup_12a22fe9f89ef8ce2f5282f4f0012e96)
#         ;
#
#
#
#
#             marker_807f6fbbaa91b6c1b1553298f3a39be8.bindTooltip(
#                 `&lt;div&gt;
#                      html string
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3.7 Tooltip
# 用来设置提示内容

# %% [markdown]
# ```python
# folium.Tooltip(
#     text:  提示的内容，字符串，如果不是字符串则会被转为字符串
#     style: HTML内联样式，将会使用<div>节点
#     sticky: 默认为True，控制在可显示提示的区域内移动鼠标，提示是否随着鼠标移动
# )
# ```

# %% [markdown]
# # 4. vector_layers下的类

# %% [markdown]
# ## 4.1 Circle
# 用来在地图上绘制圆形，圆形的大小会随着地图的缩放而改变

# %% [markdown]
# ```python
# folium.Circle(
#     location=None,   圆心坐标，元组或者列表，[latitude, longitude]
#     radius=50,       半径，以米为单位，此处的半径为实际距离
#     popup=None,      点击时出现的文本
#          - 字符串
#          - html字符串  实际是folium.Popup实例化
#          - folium.Popup对象
#     tooltip=None     鼠标移动上去时显示的文本
#         - 字符串
#         - folium.Tooltip对象
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=9,
    control_scale=True
)

m = folium.Marker(
    location=[30.6568, 104.0686]
)

c = folium.Circle(
    location=[30.6568, 104.0686],
    radius=1000,
    popup='scaled circle',
    tooltip='folium.Circle'
)
map.add_child(m)
map.add_child(c)
map.add_child(
    plugins.MeasureControl()
)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7e185baf8aafe6b9270dc3e5c6062b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7e185baf8aafe6b9270dc3e5c6062b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7e185baf8aafe6b9270dc3e5c6062b0 = L.map(
#                 &quot;map_b7e185baf8aafe6b9270dc3e5c6062b0&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b7e185baf8aafe6b9270dc3e5c6062b0);
#
#
#
#
#
#             var tile_layer_540f7920f34c6de0cd861a4eacfd9dd4 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7e185baf8aafe6b9270dc3e5c6062b0);
#
#
#             var marker_c4377dbd584493e52682ce773aed2288 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(map_b7e185baf8aafe6b9270dc3e5c6062b0);
#
#
#             var circle_f5901b07cb204c0b5dc1bd50d60e2c60 = L.circle(
#                 [30.6568, 104.0686],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7e185baf8aafe6b9270dc3e5c6062b0);
#
#
#         var popup_a280d7cb57c2cea77057211a2af4dde5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0015f0fee4b71aeacf6e3286bdd3880f = $(`&lt;div id=&quot;html_0015f0fee4b71aeacf6e3286bdd3880f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;scaled circle&lt;/div&gt;`)[0];
#                 popup_a280d7cb57c2cea77057211a2af4dde5.setContent(html_0015f0fee4b71aeacf6e3286bdd3880f);
#
#
#
#         circle_f5901b07cb204c0b5dc1bd50d60e2c60.bindPopup(popup_a280d7cb57c2cea77057211a2af4dde5)
#         ;
#
#
#
#
#             circle_f5901b07cb204c0b5dc1bd50d60e2c60.bindTooltip(
#                 `&lt;div&gt;
#                      folium.Circle
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var measure_control_e2bae426895645ff379f0ce5a0562239 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;topright&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_b7e185baf8aafe6b9270dc3e5c6062b0.addControl(measure_control_e2bae426895645ff379f0ce5a0562239);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4.2 CircleMarker
# 用来在地图上绘制圆形，圆形的大小不随着地图的缩放而改变

# %% [markdown]
# ```python
# folium.CircleMarker(
#     location=None,   圆心坐标，元组或者列表，[latitude, longitude]
#     radius=50,       半径，以米为单位
#     popup=None,      点击时出现的文本
#          - 字符串
#          - html字符串  实际是folium.Popup实例化
#          - folium.Popup对象
#     tooltip=None     鼠标移动上去时显示的文本
#         - 字符串
#         - folium.Tooltip对象
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=9,
    control_scale=True
)

m = folium.Marker(
    location=[30.6568, 104.0686]
)

c = folium.CircleMarker(
    location=[30.6568, 104.0686],
    radius=500,
    popup='scaled circle',
    tooltip='folium.Circle'
)
map.add_child(m)
map.add_child(c)
map.add_child(
    plugins.MeasureControl()
)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86972e260d741f5e06a51ff742d7d120 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86972e260d741f5e06a51ff742d7d120&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86972e260d741f5e06a51ff742d7d120 = L.map(
#                 &quot;map_86972e260d741f5e06a51ff742d7d120&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_86972e260d741f5e06a51ff742d7d120);
#
#
#
#
#
#             var tile_layer_e118ecb60085572b5f92f02a6f54209b = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86972e260d741f5e06a51ff742d7d120);
#
#
#             var marker_ce6a24e572c5a3f9c872aedc2ee4a7b7 = L.marker(
#                 [30.6568, 104.0686],
#                 {}
#             ).addTo(map_86972e260d741f5e06a51ff742d7d120);
#
#
#             var circle_marker_c07e5ce90bc4e1b7ffb7a04c85884a78 = L.circleMarker(
#                 [30.6568, 104.0686],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86972e260d741f5e06a51ff742d7d120);
#
#
#         var popup_d7ff87ea16071efe5aea01d72d4cc4b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffb867fb2c145d23dad7bcfd637f9531 = $(`&lt;div id=&quot;html_ffb867fb2c145d23dad7bcfd637f9531&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;scaled circle&lt;/div&gt;`)[0];
#                 popup_d7ff87ea16071efe5aea01d72d4cc4b8.setContent(html_ffb867fb2c145d23dad7bcfd637f9531);
#
#
#
#         circle_marker_c07e5ce90bc4e1b7ffb7a04c85884a78.bindPopup(popup_d7ff87ea16071efe5aea01d72d4cc4b8)
#         ;
#
#
#
#
#             circle_marker_c07e5ce90bc4e1b7ffb7a04c85884a78.bindTooltip(
#                 `&lt;div&gt;
#                      folium.Circle
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var measure_control_319cdec420c40866b645c9ddb0fdad10 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;topright&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_86972e260d741f5e06a51ff742d7d120.addControl(measure_control_319cdec420c40866b645c9ddb0fdad10);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4.3 PolyLine
# 用来在地图上根据给定的经纬度绘制直线

# %% [markdown]
# ```python
# folium.PolyLine(
#     locations,
#     popup,
#     tooltip,
#     smooth_factor=1.0,  在每个缩放级别上，简化polyline的程度，越大意味着越好的性能和流畅的外观，越小意味着越精准
#     no_clip=False       禁止泼polyline
# )
# ```

# %%
metro_18 = pd.read_excel('metro_18号线.xlsx')

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True
)

map.add_child(
    folium.PolyLine(
        locations=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()],
        tooltip='Line 18', 
        popup='Line 18',
        color='#3c898a'
    )
)
    
map.add_child(
    plugins.MarkerCluster(
        locations=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()],
        popups=[ folium.Popup(x['metro_station'], max_width=100) for name, x in metro_18.iterrows()],
        tooltips=[ x['metro_station'] for name, x in metro_18.iterrows()]
    )
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e5cc0bf83089355c03e96d094934f95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e5cc0bf83089355c03e96d094934f95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e5cc0bf83089355c03e96d094934f95 = L.map(
#                 &quot;map_6e5cc0bf83089355c03e96d094934f95&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6e5cc0bf83089355c03e96d094934f95);
#
#
#
#
#
#             var tile_layer_32a03c3238a38b9f39b90d2d978e8530 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e5cc0bf83089355c03e96d094934f95);
#
#
#             var poly_line_eac85f40589aa8f7575730663e01269e = L.polyline(
#                 [[30.605459, 104.067393], [30.575873, 104.064313], [30.568417, 104.069417], [30.55487, 104.06893], [30.492778, 104.071583], [30.424349, 104.074399], [30.409471, 104.102652], [30.311344, 104.317235], [30.31098, 104.444132], [30.338264, 104.456853]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3c898a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3c898a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6e5cc0bf83089355c03e96d094934f95);
#
#
#         var popup_61d788292d41aa68f3e0a8f8aa5bd5c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bfcd5035f7d37846fe8d2ea7cfcde5a = $(`&lt;div id=&quot;html_9bfcd5035f7d37846fe8d2ea7cfcde5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Line 18&lt;/div&gt;`)[0];
#                 popup_61d788292d41aa68f3e0a8f8aa5bd5c1.setContent(html_9bfcd5035f7d37846fe8d2ea7cfcde5a);
#
#
#
#         poly_line_eac85f40589aa8f7575730663e01269e.bindPopup(popup_61d788292d41aa68f3e0a8f8aa5bd5c1)
#         ;
#
#
#
#
#             poly_line_eac85f40589aa8f7575730663e01269e.bindTooltip(
#                 `&lt;div&gt;
#                      Line 18
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cluster_e23a4e2bf1ef15d10f7667a713e436c2 = L.markerClusterGroup(
#                 {&quot;tooltips&quot;: [&quot;\u706b\u8f66\u5357\u7ad9&quot;, &quot;\u5b75\u5316\u56ed&quot;, &quot;\u9526\u57ce\u5e7f\u573a\u4e1c&quot;, &quot;\u4e16\u7eaa\u57ce&quot;, &quot;\u6d77\u660c\u8def&quot;, &quot;\u897f\u535a\u57ce&quot;, &quot;\u5174\u9686&quot;, &quot;\u4e09\u5c94&quot;, &quot;\u5929\u5e9c\u673a\u573a1\u53f72\u53f7\u822a\u7ad9\u697c&quot;, &quot;\u5929\u5e9c\u673a\u573a\u5317&quot;]}
#             );
#             map_6e5cc0bf83089355c03e96d094934f95.addLayer(marker_cluster_e23a4e2bf1ef15d10f7667a713e436c2);
#
#
#             var marker_5f239c92afb66ad42ba1fd8602567492 = L.marker(
#                 [30.605459, 104.067393],
#                 {}
#             ).addTo(marker_cluster_e23a4e2bf1ef15d10f7667a713e436c2);
#
#
#         var popup_aaa7fe1dd928c8c435591aaed5ec837b = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_f39de3818bddad7096a04a83115638e9 = $(`&lt;div id=&quot;html_f39de3818bddad7096a04a83115638e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;火车南站&lt;/div&gt;`)[0];
#                 popup_aaa7fe1dd928c8c435591aaed5ec837b.setContent(html_f39de3818bddad7096a04a83115638e9);
#
#
#
#         marker_5f239c92afb66ad42ba1fd8602567492.bindPopup(popup_aaa7fe1dd928c8c435591aaed5ec837b)
#         ;
#
#
#
#
#             var marker_768ab4b7edcad38f033cb97de88979f6 = L.marker(
#                 [30.575873, 104.064313],
#                 {}
#             ).addTo(marker_cluster_e23a4e2bf1ef15d10f7667a713e436c2);
#
#
#         var popup_6d14698f9df63a125ccc03998d1bb12a = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_df7e9733d2a771bc8f813d6d0df976fe = $(`&lt;div id=&quot;html_df7e9733d2a771bc8f813d6d0df976fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;孵化园&lt;/div&gt;`)[0];
#                 popup_6d14698f9df63a125ccc03998d1bb12a.setContent(html_df7e9733d2a771bc8f813d6d0df976

# %%
folium.PolyLine?
# Out:
# Init signature: folium.PolyLine(locations, popup=None, tooltip=None, **kwargs)
# Docstring:
# Draw polyline overlays on a map.
#
# See :func:`folium.vector_layers.path_options` for the `Path` options.
#
# Parameters
# ----------
# locations: list of points (latitude, longitude)
#     Latitude and Longitude of line (Northing, Easting)
# popup: str or folium.Popup, default None
#     Input text or visualization for object displayed when clicking.
# tooltip: str or folium.Tooltip, default None
#     Display a text when hovering over the object.
# smooth_factor: float, default 1.0
#     How much to simplify the polyline on each zoom level.
#     More means better performance and smoother look,
#     and less means more accurate representation.
# no_clip: Bool, default False
#     Disable polyline clipping.
# **kwargs
#     Other valid (possibly inherited) options. See:
#     https://leafletjs.com/reference-1.6.0.html#polyline
# File:           d:\programs\anaconda3\lib\site-packages\folium\vector_layers.py
# Type:           type
# Subclasses:     PolyLineOffset

# %% [markdown]
# ## 4.4 Polygon
# 用来在地图上根据给定的经纬度绘制多边形

# %% [markdown]
# ```python
# folium.Polygon(
#     locations,
#     popup,
#     tooltip,
# )
# ```

# %%
metro_18 = pd.read_excel('metro_18号线.xlsx')

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True
)

map.add_child(
    folium.Polygon(
        locations=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()],
        tooltip='Line 18', 
        popup='Line 18',
        color='#3c898a'
    )
)
    
map.add_child(
    plugins.MarkerCluster(
        locations=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()],
        popups=[ folium.Popup(x['metro_station'], max_width=100) for name, x in metro_18.iterrows()],
        tooltips=[ x['metro_station'] for name, x in metro_18.iterrows()]
    )
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4f17802731e6ff7984b25979fb25030 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4f17802731e6ff7984b25979fb25030&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4f17802731e6ff7984b25979fb25030 = L.map(
#                 &quot;map_e4f17802731e6ff7984b25979fb25030&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e4f17802731e6ff7984b25979fb25030);
#
#
#
#
#
#             var tile_layer_a5595f5c976050c3d8f3623c82eca9d5 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e4f17802731e6ff7984b25979fb25030);
#
#
#             var polygon_4e9d000ad883d617168d11755cbe7b78 = L.polygon(
#                 [[30.605459, 104.067393], [30.575873, 104.064313], [30.568417, 104.069417], [30.55487, 104.06893], [30.492778, 104.071583], [30.424349, 104.074399], [30.409471, 104.102652], [30.311344, 104.317235], [30.31098, 104.444132], [30.338264, 104.456853]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3c898a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3c898a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e4f17802731e6ff7984b25979fb25030);
#
#
#         var popup_af54d50878efb9ca7e74628cb14e0866 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7783dc3189ac72546be7c00fb6a158c8 = $(`&lt;div id=&quot;html_7783dc3189ac72546be7c00fb6a158c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Line 18&lt;/div&gt;`)[0];
#                 popup_af54d50878efb9ca7e74628cb14e0866.setContent(html_7783dc3189ac72546be7c00fb6a158c8);
#
#
#
#         polygon_4e9d000ad883d617168d11755cbe7b78.bindPopup(popup_af54d50878efb9ca7e74628cb14e0866)
#         ;
#
#
#
#
#             polygon_4e9d000ad883d617168d11755cbe7b78.bindTooltip(
#                 `&lt;div&gt;
#                      Line 18
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cluster_4d82037f47ba9590a10e75cb7e8b09c8 = L.markerClusterGroup(
#                 {&quot;tooltips&quot;: [&quot;\u706b\u8f66\u5357\u7ad9&quot;, &quot;\u5b75\u5316\u56ed&quot;, &quot;\u9526\u57ce\u5e7f\u573a\u4e1c&quot;, &quot;\u4e16\u7eaa\u57ce&quot;, &quot;\u6d77\u660c\u8def&quot;, &quot;\u897f\u535a\u57ce&quot;, &quot;\u5174\u9686&quot;, &quot;\u4e09\u5c94&quot;, &quot;\u5929\u5e9c\u673a\u573a1\u53f72\u53f7\u822a\u7ad9\u697c&quot;, &quot;\u5929\u5e9c\u673a\u573a\u5317&quot;]}
#             );
#             map_e4f17802731e6ff7984b25979fb25030.addLayer(marker_cluster_4d82037f47ba9590a10e75cb7e8b09c8);
#
#
#             var marker_7cd1e3ce05aef80725856646df1b96ff = L.marker(
#                 [30.605459, 104.067393],
#                 {}
#             ).addTo(marker_cluster_4d82037f47ba9590a10e75cb7e8b09c8);
#
#
#         var popup_c5455370993b0d2d49a2f1cbc93670d3 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_d43e0e62233e2cb34e372a0fbafe2e21 = $(`&lt;div id=&quot;html_d43e0e62233e2cb34e372a0fbafe2e21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;火车南站&lt;/div&gt;`)[0];
#                 popup_c5455370993b0d2d49a2f1cbc93670d3.setContent(html_d43e0e62233e2cb34e372a0fbafe2e21);
#
#
#
#         marker_7cd1e3ce05aef80725856646df1b96ff.bindPopup(popup_c5455370993b0d2d49a2f1cbc93670d3)
#         ;
#
#
#
#
#             var marker_71184f4df38476c609842fa571a69797 = L.marker(
#                 [30.575873, 104.064313],
#                 {}
#             ).addTo(marker_cluster_4d82037f47ba9590a10e75cb7e8b09c8);
#
#
#         var popup_6b4eba230b9e4c4c7b66c422f88d30cd = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_96866268dcc48182b6f3fb356af85756 = $(`&lt;div id=&quot;html_96866268dcc48182b6f3fb356af85756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;孵化园&lt;/div&gt;`)[0];
#                 popup_6b4eba230b9e4c4c7b66c422f88d30cd.setContent(html_96866268dcc48182b6f3fb356af85756);

# %% [markdown]
# ## 4.5 Rectangle
# 根据给定的点绘制叠加的矩形区域

# %% [markdown]
# ```python
# folium.Rectangle(
#     bounds,    [lat, lng]组成的列表，在每个给定的点绘制水平线和垂直线，所有点组成的最大的矩形，不一定每个点都在矩形边上
#     popup,
#     tooltip
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True
)

map.add_child(
    folium.Rectangle(
        bounds=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()]
    )
)
    
map.add_child(
    plugins.MarkerCluster(
        locations=[ [x['metro_lat'], x['metro_lng']] for name, x in metro_18.iterrows()],
        popups=[ folium.Popup(x['metro_station'], max_width=100) for name, x in metro_18.iterrows()],
        tooltips=[ x['metro_station'] for name, x in metro_18.iterrows()]
    )
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9db571e3d02b82234882d49722b5284 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9db571e3d02b82234882d49722b5284&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9db571e3d02b82234882d49722b5284 = L.map(
#                 &quot;map_e9db571e3d02b82234882d49722b5284&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e9db571e3d02b82234882d49722b5284);
#
#
#
#
#
#             var tile_layer_828fcde42515b752790f05b28b51c1d0 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9db571e3d02b82234882d49722b5284);
#
#
#             var rectangle_ba33cbad7f037485a2367f77dfcddbce = L.rectangle(
#                 [[30.605459, 104.067393], [30.575873, 104.064313], [30.568417, 104.069417], [30.55487, 104.06893], [30.492778, 104.071583], [30.424349, 104.074399], [30.409471, 104.102652], [30.311344, 104.317235], [30.31098, 104.444132], [30.338264, 104.456853]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e9db571e3d02b82234882d49722b5284);
#
#
#             var marker_cluster_703764a69b2a835361d595bf5518364c = L.markerClusterGroup(
#                 {&quot;tooltips&quot;: [&quot;\u706b\u8f66\u5357\u7ad9&quot;, &quot;\u5b75\u5316\u56ed&quot;, &quot;\u9526\u57ce\u5e7f\u573a\u4e1c&quot;, &quot;\u4e16\u7eaa\u57ce&quot;, &quot;\u6d77\u660c\u8def&quot;, &quot;\u897f\u535a\u57ce&quot;, &quot;\u5174\u9686&quot;, &quot;\u4e09\u5c94&quot;, &quot;\u5929\u5e9c\u673a\u573a1\u53f72\u53f7\u822a\u7ad9\u697c&quot;, &quot;\u5929\u5e9c\u673a\u573a\u5317&quot;]}
#             );
#             map_e9db571e3d02b82234882d49722b5284.addLayer(marker_cluster_703764a69b2a835361d595bf5518364c);
#
#
#             var marker_18b0a892e8e738975160cc504e5a7ad7 = L.marker(
#                 [30.605459, 104.067393],
#                 {}
#             ).addTo(marker_cluster_703764a69b2a835361d595bf5518364c);
#
#
#         var popup_d63b94272a2bbead06b018e51effe670 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_617846347c518d011280a295f304fea3 = $(`&lt;div id=&quot;html_617846347c518d011280a295f304fea3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;火车南站&lt;/div&gt;`)[0];
#                 popup_d63b94272a2bbead06b018e51effe670.setContent(html_617846347c518d011280a295f304fea3);
#
#
#
#         marker_18b0a892e8e738975160cc504e5a7ad7.bindPopup(popup_d63b94272a2bbead06b018e51effe670)
#         ;
#
#
#
#
#             var marker_0c14b52e0d1f76d6fc1eb4c78fb3c0e5 = L.marker(
#                 [30.575873, 104.064313],
#                 {}
#             ).addTo(marker_cluster_703764a69b2a835361d595bf5518364c);
#
#
#         var popup_e8c27475c0d674cbb42c8ebf6de21bab = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_610bb4421c0251254f77afad7bbf42bb = $(`&lt;div id=&quot;html_610bb4421c0251254f77afad7bbf42bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;孵化园&lt;/div&gt;`)[0];
#                 popup_e8c27475c0d674cbb42c8ebf6de21bab.setContent(html_610bb4421c0251254f77afad7bbf42bb);
#
#
#
#         marker_0c14b52e0d1f76d6fc1eb4c78fb3c0e5.bindPopup(popup_e8c27475c0d674cbb42c8ebf6de21bab)
#         ;
#
#
#
#
#             var marker_8c51e49c65231b7b34e42ac7e1a17f76 = L.marker(
#                 [30.568417, 104.069417],
#                 {}
#             ).addTo(marker_cluster_703764a69b2a835361d595bf5518364c);
#
#
#         var popup_0307698f1a4789ccac49da35a456ba3b = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_0d2e6af273917c8b9d5bdea965b1147a = $(`&lt;div id=&quot;html_0d2e6af273917c8b9d5bdea965b1147a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;锦城广场东&lt;/div&gt;`)[0];
#                 popup_0307698f1a4789ccac49da35a456ba3b.setContent(html_0d2e6af273917c8b9d5bdea965b1147a);

# %% [markdown]
# # 5. raster_layers下的类

# %% [markdown]
# ## 5.1 TileLayer
# 为地图附加一个瓦片图层

# %% [markdown]
# ```python
# TileLayer(
#     tiles='OpenStreetMap',  瓦片
#     min_zoom=0,
#     max_zoom=18,
#     max_native_zoom=None,
#     attr=None,
#     detect_retina=False,
#     name=None,
#     overlay=False,
#     control=True,
#     show=True,
#     no_wrap=False,
#     subdomains='abc',
#     tms=False,
#     opacity=1,
#     **kwargs,
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

# 增加额外瓦片图层
gaode_satellite = folium.TileLayer(
    tiles='https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=6&ltype=4',
    # tiles='http://webst0{1-4}.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
    attr='高德-卫星图',
    overlay=False ,# False表示基础图层，与Map定义中的互斥选择，True表示叠加图层，覆盖
    name='satellite'
)

map.add_child(gaode_satellite)

map.add_child(
    folium.LayerControl()  # 添加LayerControl，供以选择基础图层
)



map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36a357ad7bd3b739419005ff827ae5fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36a357ad7bd3b739419005ff827ae5fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36a357ad7bd3b739419005ff827ae5fa = L.map(
#                 &quot;map_36a357ad7bd3b739419005ff827ae5fa&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_36a357ad7bd3b739419005ff827ae5fa);
#
#
#
#
#
#             var tile_layer_330ddf2b9d6d8132b1853cb558578b00 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36a357ad7bd3b739419005ff827ae5fa);
#
#
#             var tile_layer_cc92aa88f32fe71a0575628fef836d4c = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=6\u0026ltype=4&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u536b\u661f\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36a357ad7bd3b739419005ff827ae5fa);
#
#
#             var layer_control_b07b691c67725c54ff9cc0e178b0bbc5 = {
#                 base_layers : {
#                     &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot; : tile_layer_330ddf2b9d6d8132b1853cb558578b00,
#                     &quot;satellite&quot; : tile_layer_cc92aa88f32fe71a0575628fef836d4c,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_b07b691c67725c54ff9cc0e178b0bbc5.base_layers,
#                 layer_control_b07b691c67725c54ff9cc0e178b0bbc5.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_36a357ad7bd3b739419005ff827ae5fa);
#             tile_layer_cc92aa88f32fe71a0575628fef836d4c.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5.2 WmsTileLayer
# 用于添加一个Web Map Service，目前没找到国内的wms

# %% [markdown]
# ```python
# folium.WmsTileLayer(
#     url,                wms的url
#     layers,             用于展示的，使用逗号分隔的wms图层
#     styles='',          使用逗号分隔的wms样式
#     fmt='image/jpeg',   wms输出的格式
#     transparent=False,  是否允许透明
#     version='1.1.1',    wms服务使用的版本
#     attr='',            wms服务的属性
#     name=None,
#     overlay=True,
#     control=True,
#     show=True,
#     **kwargs,
# )
# ```

# %%
# 没找到国内wms，因此此处样例采取官方样例

m = folium.Map(location=[41, -70], zoom_start=5, tiles=None)


folium.raster_layers.TileLayer(
    tiles="http://{s}.google.com/vt/lyrs=s&x={x}&y={y}&z={z}",
    attr="google",
    name="google maps",
    max_zoom=20,
    subdomains=["mt0", "mt1", "mt2", "mt3"],
    overlay=False,
    control=True,
).add_to(m)

folium.raster_layers.TileLayer(
    tiles="http://{s}.google.com/vt/lyrs=m&x={x}&y={y}&z={z}",
    attr="google",
    name="google street view",
    max_zoom=20,
    subdomains=["mt0", "mt1", "mt2", "mt3"],
    overlay=False,
    control=True,
).add_to(m)


folium.raster_layers.WmsTileLayer(
    url="http://mesonet.agron.iastate.edu/cgi-bin/wms/nexrad/n0r.cgi",
    name="test",
    fmt="image/png",
    layers="nexrad-n0r-900913",
    attr=u"Weather data © 2012 IEM Nexrad",
    transparent=True,
    overlay=True,
    control=True,
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_346c96a372417b92417d2e6815161317 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_346c96a372417b92417d2e6815161317&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_346c96a372417b92417d2e6815161317 = L.map(
#                 &quot;map_346c96a372417b92417d2e6815161317&quot;,
#                 {
#                     center: [41.0, -70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a317a96aa0882e5383ff54b5bb3d42b9 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: [&quot;mt0&quot;, &quot;mt1&quot;, &quot;mt2&quot;, &quot;mt3&quot;], &quot;tms&quot;: false}
#             ).addTo(map_346c96a372417b92417d2e6815161317);
#
#
#             var tile_layer_eebb642312c80252772d6ede1811c60f = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: [&quot;mt0&quot;, &quot;mt1&quot;, &quot;mt2&quot;, &quot;mt3&quot;], &quot;tms&quot;: false}
#             ).addTo(map_346c96a372417b92417d2e6815161317);
#
#
#             var macro_element_9517b924524eba7c65ec1b9741b84ab7 = L.tileLayer.wms(
#                 &quot;http://mesonet.agron.iastate.edu/cgi-bin/wms/nexrad/n0r.cgi&quot;,
#                 {&quot;attribution&quot;: &quot;Weather data \u00a9 2012 IEM Nexrad&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;nexrad-n0r-900913&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             ).addTo(map_346c96a372417b92417d2e6815161317);
#
#
#             var layer_control_3f94529aeee3b0710558ed5802d0156e = {
#                 base_layers : {
#                     &quot;google maps&quot; : tile_layer_a317a96aa0882e5383ff54b5bb3d42b9,
#                     &quot;google street view&quot; : tile_layer_eebb642312c80252772d6ede1811c60f,
#                 },
#                 overlays :  {
#                     &quot;test&quot; : macro_element_9517b924524eba7c65ec1b9741b84ab7,
#                 },
#             };
#             L.control.layers(
#                 layer_control_3f94529aeee3b0710558ed5802d0156e.base_layers,
#                 layer_control_3f94529aeee3b0710558ed5802d0156e.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_346c96a372417b92417d2e6815161317);
#             tile_layer_eebb642312c80252772d6ede1811c60f.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 6. feature下的类

# %% [markdown]
# ## 6.1 Choropleth
# 绘制分级统计图
# - 为基础地图添加一个GeoJson图层
#     - 在基础地图上绘制一个GeoJson图层，不是必须绑定数据
#         - 只传递一个GeoJson数据会在地图上绘制一个单一颜色的图层
#         - 如果传递了数据，会以不同颜色体现不同数
#             - 如果传递了`Pandas.DataFrame`，则`columns`和`key-on`参数必须赋值
#                 - `columns` 指明DataFrame中使用的列
#                 - `key-on`  指明了GeoJson中那部分对应到DataFrame的列
#             - 颜色是通过color brewer产生的
#             - TopoJson数据可以传递给`geo_data`参数，此时`topojson`参数必须赋值为需要转换的topojson对象的引用

# %% [markdown]
# ```python
# folium.Choropleth(
#     geo_data,                  geojson数据，可以是url，文件路径，或数据(json, dict, geopandas等)
#     data=None,                 绑定到geojson上的数据，可以是DataFrame或者Series
#     columns=None,              DataFrame中使用的列，如果是Series可以不指定
#     key_on=None,               geo_data中绑定数据的属性，必须是feature开头的
#     bins=6,                    可以是整数，整数序列，可参照`numpy.histogram`中的参数
#                                    - 整数指明色阶的个数
#                                    - 列表指明具体值落入色阶中的哪部分
#     fill_color=None,           填充颜色，默认是蓝色，可以传递十六进制颜色编码或者颜色字符串，如果传递了`data`参数，可以使用如下色阶
#                                'BuGn', 'BuPu', 'GnBu', 'OrRd', 'PuBu', 'PuBuGn', 'PuRd', 'RdPu', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd'
#     nan_fill_color='black',    缺失值的填充颜色，默认黑色，可以传递十六进制颜色编码或者颜色字符串
#     fill_opacity=0.6,          透明度，1不透明，0完全透明
#     nan_fill_opacity=None,     缺失值的填充颜色的透明度
#     line_color='black',        geojson中界线的颜色
#     line_weight=1,             geojson中界线的粗细
#     line_opacity=1,            geojson中界线的透明度
#     name=None,                 LayerControl中的名字
#     legend_name='',            图例名字
#     overlay=True,
#     control=True,
#     show=True,
#     topojson=None,             如果geo_data传递的是TopoJson，则此处指明形如'objects.yourfeature'的值，则将会自动将TopoJson转为GeoJson
#     smooth_factor=None,
#     highlight=None,            鼠标悬停在区域上时是否高亮该区域
#     **kwargs,
# )
# ```

# %%
cd_geo_json = 'https://geo.datav.aliyun.com/areas_v3/bound/geojson?code=510100_full'
cd_data = pd.Series(range(1,21), index=['锦江区','青羊区','金牛区','武侯区','成华区','龙泉驿区','青白江区','新都区','温江区','双流区','郫都区','新津区','金堂县','大邑县','蒲江县','都江堰市','彭州市','邛崃市','崇州市','简阳市'])

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

map.add_child(
    folium.Choropleth(
        geo_data=cd_geo_json,
        data=cd_data,
        key_on='feature.properties.name',
        bins=8,
        fill_color='YlGn',
        fill_opacity=0.2,
        line_color='orange',
        line_weight=2,
        highlight=True,
        legend='Choropleth'
    )
)



map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f7087333fb198cdb0d6f4f1a3e3eff8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f7087333fb198cdb0d6f4f1a3e3eff8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f7087333fb198cdb0d6f4f1a3e3eff8 = L.map(
#                 &quot;map_5f7087333fb198cdb0d6f4f1a3e3eff8&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5f7087333fb198cdb0d6f4f1a3e3eff8);
#
#
#
#
#
#             var tile_layer_46e663b2f241fd2386df144d074ee5e8 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f7087333fb198cdb0d6f4f1a3e3eff8);
#
#
#             var choropleth_68c7a25addee96cf39f076730b3e955c = L.featureGroup(
#                 {}
#             ).addTo(map_5f7087333fb198cdb0d6f4f1a3e3eff8);
#
#
#         function geo_json_2ccc666b9c17b78498638f5f1ace3c61_styler(feature) {
#             switch(feature.properties.adcode) {
#                 case 510107: case 510108:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#f7fcb9&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510112: case 510113: case 510114:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510115: case 510116:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510117: case 510118:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510121: case 510129: case 510131:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#41ab5d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510181: case 510182:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#238443&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 case 510183: case 510184: case 510185:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#005a32&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;orange&quot;, &quot;fillColor&quot;: &quot;#ffffe5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2ccc666b9c17b78498638f5f1ace3c61_highlighter(feature) {
#             switch(feature.properties.adcode) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_2ccc666b9c17b78498638f5f1ace3c61_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_2ccc666b9c17b78498638f5f1ace3c61.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2ccc666b9c17b78498638f5f1ace3c61_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2ccc666b9c17b78498638f5f1ace3c61 = L.geoJson(null, {
#                 onEachFeature: geo_json_2ccc666b9c17b78498638f5f1ace3c61_onEachFeature,
#
#                 style: geo_json_2ccc666b9c17b78498638f5f1ace3c61_styler,
#         });
#
#         function geo_json_2ccc666b9c17b78498638f5f1ace3c61_add (data) {
#             geo_json_2ccc666b9c17b78498638f5f1ace3c61
#                 .addData(data)
#                 .addTo(choropleth_68c7a25addee96cf39f076730b3e955c);
#         }
#             geo_json_2ccc666b9c17b78498638f5f1ace3c61_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[104.059956, 30.647001], [104.064698, 30.646772], [104.07864, 30.64529], [104.084926, 30.641975], [104.087707, 30.64122], [104.09083, 30.637946], [104.09422, 30.630223], [104.092982, 30.62711], [104.086468, 30.626032], [104.084564, 30.623687], [104.085707, 30.619333], [104.084526, 30.61653], [104.088049

# %% [markdown]
# ## 6.2 ClickForMarker
# 鼠标点击地图，添加图钉

# %% [markdown]
# ```python
# folium.ClickForMarker(
#     popup=None      字符串，弹出框的文本，如果是None则默认为经纬度
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

f1 = folium.FeatureGroup('f1')
f2 = folium.FeatureGroup('f2')

# f1.add_to(map)
# f2.add_to(map)

# f1.add_child(
#     folium.ClickForMarker()
# )

# f2.add_child(
#     folium.ClickForMarker('a.b.c.d')
# )

# map.add_child(
#     folium.LayerControl()
# )

map.add_child(
    folium.ClickForMarker()
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61f73a972cd071417978e0477b5d0076 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61f73a972cd071417978e0477b5d0076&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61f73a972cd071417978e0477b5d0076 = L.map(
#                 &quot;map_61f73a972cd071417978e0477b5d0076&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_61f73a972cd071417978e0477b5d0076);
#
#
#
#
#
#             var tile_layer_9e976c55de36d70f018e640dc7a4c79d = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61f73a972cd071417978e0477b5d0076);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_61f73a972cd071417978e0477b5d0076);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_61f73a972cd071417978e0477b5d0076.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(&quot;Latitude: &quot; + lat + &quot;&lt;br&gt;Longitude: &quot; + lng );
#                     };
#                 map_61f73a972cd071417978e0477b5d0076.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6.3 ColorLine
# 在地图上根据给定的点添加不同颜色的线条
# 参数`colors`,`colormap`,`nb_steps`共同决定了线条颜色以及线条绘制，概括来说`colors`和`nb_steps`共同决定使用颜色图中的具体颜色，`colormap`确定使用哪个颜色图
# - `colors`     长度为`len(positions) - 1`的列表或者元组
#     - 长度为len(positions) - 1，是因为在源码中，使用positions和colors做zip操作，因此要保持一致，否知绘制的线段会缺失
#     - 内容是数字，而不是颜色字符串，最小值会传递给`colormap`的`vmin`参数，最大值会传递给`colormap`的`vmax`参数
#         - vmin: Values lower than `vmin` will be bound directly to `colors[0]`
#         - vmax: Values higher than `vmin` will be bound directly to `colors[0]`
#         - 经过测试初步发现是线段序号和`vmin`&`vmax`比较
#         - 中间的会对应序号从`colormap`中取数
# - `colormap`   使用的色图 可以使branca.colormap.ColorMap实例，也可以是颜色字符串组成的列表或者元组
#     - 最终都会形成branca.colormap.ColorMap
# - `nb_steps`   可以理解为具体的颜色个数
#     - 如果个数小于线段数-1，则会有相同颜色的线段
#     - 如果colors设置的异常，不管该值是否小于线段数-1，都会出现相同颜色

# %% [markdown]
# ```python
# folium.ColorLine(
#     positions,         [lat, lng]组成的列表或者元组
#     colors,            颜色列表或元组，长度必须是positions-1
#     colormap=None,     branca.colormap.Colormap 对象或列表或元组，颜色图，如果是元组或者列表，则通过其中的颜色生成线性颜色图
#     nb_steps=12,       为了获取更浅的输出，colormap中的颜色将会被离散到该参数个颜色
#     weight=None,       边线粗细
#     opacity=None,      透明度
#     **kwargs,
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

pts = [[30.6555, 104.0507], [30.6547, 104.0809], [30.6422, 104.1003], [30.6178, 104.0922], [30.6098, 104.0424]]

f1 = folium.FeatureGroup('f1')
f2 = folium.FeatureGroup('f2')
f3 = folium.FeatureGroup('f3')
f4 = folium.FeatureGroup('f4')

map.add_child(f1)
map.add_child(f2)
map.add_child(f3)
map.add_child(f4)

map.add_child(
    plugins.MarkerCluster(
        locations=pts,
        control=False
    )
)

f1.add_child(
    folium.ColorLine(
        positions=pts,
        colors=[10,20,30,40],
        weight=10,
        nb_steps=6
    )
)

f2.add_child(
    folium.ColorLine(
        positions=pts,
        colors=[1,2,3,4],
        # colors=[10,100],
        weight=10,
        nb_steps=3
    )
)

f3.add_child(
    folium.ColorLine(
        positions=pts,
        colors=[1,1,1,4],
        weight=10,
        nb_steps=12
    )
)

f4.add_child(
    folium.ColorLine(
        positions=pts,
        colors=[1,2,3,4],
        weight=10,
        nb_steps=100
    )
)

map.add_child(
    folium.LayerControl()
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db813167580c8cb16bc08bc3888be2f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db813167580c8cb16bc08bc3888be2f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db813167580c8cb16bc08bc3888be2f2 = L.map(
#                 &quot;map_db813167580c8cb16bc08bc3888be2f2&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_db813167580c8cb16bc08bc3888be2f2);
#
#
#
#
#
#             var tile_layer_4000ee4d43a6e371d692233cf9594c1c = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_db813167580c8cb16bc08bc3888be2f2);
#
#
#             var feature_group_e4430a7fe60f27a28957d95baf55ec48 = L.featureGroup(
#                 {}
#             ).addTo(map_db813167580c8cb16bc08bc3888be2f2);
#
#
#             var color_line_74f21d98add422203d5a703c58496120 = L.featureGroup(
#                 {}
#             ).addTo(feature_group_e4430a7fe60f27a28957d95baf55ec48);
#
#
#             var poly_line_2e60b2d28b2c6129d65295341464edcb = L.polyline(
#                 [[[30.6555, 104.0507], [30.6547, 104.0809]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#008000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_74f21d98add422203d5a703c58496120);
#
#
#             var poly_line_d67e6a5489907cbc6fdfbc06a8f6cef8 = L.polyline(
#                 [[[30.6547, 104.0809], [30.6422, 104.1003]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#66b300ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#66b300ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_74f21d98add422203d5a703c58496120);
#
#
#             var poly_line_f611746cba7f79b38397f142e1591c4a = L.polyline(
#                 [[[30.6422, 104.1003], [30.6178, 104.0922]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffcc00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffcc00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_74f21d98add422203d5a703c58496120);
#
#
#             var poly_line_f7958befc9acea3e9b6175dbd901582d = L.polyline(
#                 [[[30.6178, 104.0922], [30.6098, 104.0424]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_74f21d98add422203d5a703c58496120);
#
#
#             var feature_group_cd96de048458cc7ae98a237c209db915 = L.featureGroup(
#                 {}
#             ).addTo(map_db813167580c8cb16bc08bc3888be2f2);
#
#
#             var color_line_e95f35b8c8172b922f57c44055f60f76 = L.featureGroup(
#                 {}
#             ).addTo(feature_group_cd96de048458cc7ae98a237c209db915);
#
#
#             var poly_line_6b21aef6c6aa4644662236b40e3e9ca7 = L.polyline(
#                 [[[30.6555, 104.0507], [30.6547, 104.0809]], [[30.6547

# %%
import branca
from branca import colormap

# %%
branca.colormap?
# Out:
# Type:        module
# String form: <module 'branca.colormap' from 'd:\\Programs\\Anaconda3\\lib\\site-packages\\branca\\colormap.py'>
# File:        d:\programs\anaconda3\lib\site-packages\branca\colormap.py
# Docstring:
# Colormap
# --------
#
# Utility module for dealing with colormaps.

# %% [markdown]
# ## 6.4 CustomIcon
# 使用图片等自定义图标

# %% [markdown]
# ```python
# folium.CustomIcon(
#     icon_image     需要作为图标的对象
#                         字符串
#                         文件
#                         数组 会被转为PNG based64的字符串
#     icon_size      图标大小 可选，整数构成的二元元组，表示像素
#     icon_anchor    可选，整数构成的二元元组
#     shadow_image   需要作为阴影的对象
#     shadow_size    阴影大小 可选，整数构成的二元元组，表示像素
#     shadow_anchor  可选，整数构成的二元元组
#     popup_anchor   可选，整数构成的二元元组
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

folium.Marker(
    location=[30.6555, 104.0507],
    icon=folium.CustomIcon(
        icon_image="https://img.lovepik.com/element/40053/1035.png_1200.png",
        icon_size=(50,50),
        icon_anchor=(10,10)
    )
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7e1d1512ec43491246e7de4d82c36de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7e1d1512ec43491246e7de4d82c36de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7e1d1512ec43491246e7de4d82c36de = L.map(
#                 &quot;map_e7e1d1512ec43491246e7de4d82c36de&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e7e1d1512ec43491246e7de4d82c36de);
#
#
#
#
#
#             var tile_layer_225a1976b00ced590642330b68992214 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e7e1d1512ec43491246e7de4d82c36de);
#
#
#             var marker_64f7327b317b73e69e69cca92cab38a8 = L.marker(
#                 [30.6555, 104.0507],
#                 {}
#             ).addTo(map_e7e1d1512ec43491246e7de4d82c36de);
#
#
#         var custom_icon_328c312c8874037e15671570dd64bf95 = L.icon({&quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;https://img.lovepik.com/element/40053/1035.png_1200.png&quot;});
#         marker_64f7327b317b73e69e69cca92cab38a8.setIcon(custom_icon_328c312c8874037e15671570dd64bf95);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6.5 DivIcon
# 使用div节点来创建图标，代替图片

# %% [markdown]
# ```python
# folium.DivIcon(
#     html=None,
#     icon_size=None,
#     icon_anchor=None,
#     popup_anchor=None,
#     class_name='empty',
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)


folium.Marker(
    location=[30.6555, 104.0507],
    icon=folium.DivIcon(
        # html=' <div style="font-size: 170%"> aaa </div>',
        html = """<svg height="100" width="100">
              <circle cx="50" cy="50" r="40" stroke="black" stroke-width="3" fill="red" />
              </svg>""" ,
        icon_size=(50,50),
        icon_anchor=(10,10),
    )
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c88dff647b6b0a4cc7a4eaca5ed3db1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c88dff647b6b0a4cc7a4eaca5ed3db1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c88dff647b6b0a4cc7a4eaca5ed3db1 = L.map(
#                 &quot;map_8c88dff647b6b0a4cc7a4eaca5ed3db1&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8c88dff647b6b0a4cc7a4eaca5ed3db1);
#
#
#
#
#
#             var tile_layer_beb62cf4e4b9f84cdccffd419259b090 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c88dff647b6b0a4cc7a4eaca5ed3db1);
#
#
#             var marker_0922068cb84e588184dda6378b653afc = L.marker(
#                 [30.6555, 104.0507],
#                 {}
#             ).addTo(map_8c88dff647b6b0a4cc7a4eaca5ed3db1);
#
#
#             var div_icon_f32a4a3f6c1d42ab85a3406b3ca8de7e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg height=\&quot;100\&quot; width=\&quot;100\&quot;\u003e\n              \u003ccircle cx=\&quot;50\&quot; cy=\&quot;50\&quot; r=\&quot;40\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; fill=\&quot;red\&quot; /\u003e\n              \u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [50, 50]});
#             marker_0922068cb84e588184dda6378b653afc.setIcon(div_icon_f32a4a3f6c1d42ab85a3406b3ca8de7e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6.6 GeoJson
# 读取GeoJson数据并绘制在基础地图上

# %% [markdown]
# ```python
# folium.GeoJson(
#     data,                     GeoJson数据，可以是文件，字典或者字符串
#     style_function=None,      普通时的样式，将一个样式字典映射到GeoJson的Feature，字典键值可参考： https://leafletjs.com/reference.html#path-option
#     highlight_function=None,  点击时的样式，将一个样式字典映射到GeoJson的Feature
#     name=None,
#     overlay=True,
#     control=True,
#     show=True,
#     smooth_factor=None,
#     tooltip=None,             GeoJsonTooltip/Tooltip/str类型
#     embed=True,               是否将数据嵌入到HTML文件
#     popup=None,               GeoJsonPopup类型
#     zoom_on_click=False,      点击时是否放大
#     marker=None,              Circle/CircleMarker/Marker类型
# )
# ```

# %% [markdown]
# style参数
#
# | **Option**          | **Type** | **Default** | **Description**                                                                                                                         |
# |---------------------|----------|-------------|-----------------------------------------------------------------------------------------------------------------------------------------|
# | stroke              | Boolean  | true        | Whether to draw stroke along the path. Set it to false to disable borders on polygons or circles.                                       |
# | color               | String   | '#3388ff'   | Stroke color                                                                                                                            |
# | weight              | Number   | 3           | Stroke width in pixels                                                                                                                  |
# | opacity             | Number   | 1.0         | Stroke opacity                                                                                                                          |
# | lineCap             | String   | 'round'     | A string that defines shape to be used at the end of the stroke.                                                                        |
# | lineJoin            | String   | 'round'     | A string that defines shape to be used at the corners of the stroke.                                                                    |
# | dashArray           | String   | null        | A string that defines the stroke dash pattern. Doesn't work on Canvas-powered layers in some old browsers.                              |
# | dashOffset          | String   | null        | A string that defines the distance into the dash pattern to start the dash. Doesn't work on Canvas-powered layers in some old browsers. |
# | fill                | Boolean  | depends     | Whether to fill the path with color. Set it to false to disable filling on polygons or circles.                                         |
# | fillColor           | String   | *           | Fill color. Defaults to the value of the color option                                                                                   |
# | fillOpacity         | Number   | 0.2         | Fill opacity.                                                                                                                           |
# | fillRule            | String   | 'evenodd'   | A string that defines how the inside of a shape is determined.                                                                          |
# | bubblingMouseEvents | Boolean  | true        | When true, a mouse event on this path will trigger the same event on the map (unless L.DomEvent.stopPropagation is used).               |
# | renderer            | Renderer |             | Use this specific instance of Renderer for this path. Takes precedence over the map's default renderer.                                 |
# | className           | String   | null        | Custom class name set on an element. Only for SVG renderer.                                                                             |

# %%
points = {
"type": "FeatureCollection",
"features": 
    [
        {
        "type": "Feature",
        "properties": {
        "name": "one"
            },
        "geometry": {
        "type": "Point",
        "coordinates":[ 104.02158, 30.625381]
            }
        },
        {
        "type": "Feature",
        "properties": {
        "name": "two"
            },
        "geometry": {
        "type": "Point",
        "coordinates":  [103.979376,30.54625]
            }
        },
        {
        "type": "Feature",
        "properties": {
        "name": "three"
            },
        "geometry": {
        "type": "Point",
        "coordinates": [104.107227,30.694472]
            }
        }
    ]
}

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)


folium.GeoJson(
    data=points,
    style_function=lambda feature:{
        'color': 'red',
        'fillColor':'blue'
    },
    marker=folium.Circle(radius=500, fill_color="orange", fill_opacity=0.4, color="black", weight=1),
    popup=folium.GeoJsonPopup(fields=['name'], alias=['as_a', 'as_b', 'as_c']),
    tooltip=folium.GeoJsonTooltip(fields=['name'], alias=['as_a', 'as_b', 'as_c'])
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_091686cb3a98d7f4a122aba4f9b726a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_091686cb3a98d7f4a122aba4f9b726a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_091686cb3a98d7f4a122aba4f9b726a3 = L.map(
#                 &quot;map_091686cb3a98d7f4a122aba4f9b726a3&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_091686cb3a98d7f4a122aba4f9b726a3);
#
#
#
#
#
#             var tile_layer_f6fddfd29c773b9c74788e129ead9231 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_091686cb3a98d7f4a122aba4f9b726a3);
#
#
#         function geo_json_c1a4232519c6aeea30bbaa2420b61cf0_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#         function geo_json_c1a4232519c6aeea30bbaa2420b61cf0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 1};
#
#             let style = geo_json_c1a4232519c6aeea30bbaa2420b61cf0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.circle(latlng, opts)
#         }
#
#         function geo_json_c1a4232519c6aeea30bbaa2420b61cf0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c1a4232519c6aeea30bbaa2420b61cf0 = L.geoJson(null, {
#                 onEachFeature: geo_json_c1a4232519c6aeea30bbaa2420b61cf0_onEachFeature,
#
#                 style: geo_json_c1a4232519c6aeea30bbaa2420b61cf0_styler,
#                 pointToLayer: geo_json_c1a4232519c6aeea30bbaa2420b61cf0_pointToLayer
#         });
#
#         function geo_json_c1a4232519c6aeea30bbaa2420b61cf0_add (data) {
#             geo_json_c1a4232519c6aeea30bbaa2420b61cf0
#                 .addData(data)
#                 .addTo(map_091686cb3a98d7f4a122aba4f9b726a3);
#         }
#             geo_json_c1a4232519c6aeea30bbaa2420b61cf0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [104.02158, 30.625381], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;one&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [103.979376, 30.54625], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;two&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [104.107227, 30.694472], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;three&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_c1a4232519c6aeea30bbaa2420b61cf0.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature=&gt;typeof(feature)==&#x27;object&#x27; ? JSON.stringify(feature) : feature;
#     let fields = [&quot;name&quot;];
#     let aliases = [&quot;name&quot;];
#     let table = &#x27;&lt;table&gt;&#x27; +
#         String(
#         fields.map(
#         (v,i)=&gt;
#         `&lt;tr&gt;
#             &lt;th&gt;${aliases[i]}&lt;/th&gt;
#
#             &lt;td&gt;${handleObject(layer.feature.properties[v])}&lt;/td&gt;

# %% [markdown]
# ## 6.7 GeoJsonTooltip

# %% [markdown]
# ```python
# folium.GeoJsonTooltip(
#     fields,                      用于展示的字段，列表或者元组：对于GeoJson/TopoJson数据来说，是properties下的标签，GeoDataFrame来说，是列名
#     aliases=None,                字符串的列表或元组，和fields相同长度，用于替代fields中的名称，也即别名
#     labels=True,                 是否展示标签(也即fields和alias)
#     localize=False,              是否本地化，True则使用JS中的`.toLocaleString()`来格式化成当地风格
#     style=None,                  字符串，HTML内联样式
#     class_name='foliumtooltip',
#     sticky=True,                 是否随鼠标移动
#     **kwargs,
# )
# ```

# %% [markdown]
# ## 6.8 GeoJsonPopup

# %% [markdown]
# ```python
# folium.GeoJsonPopup(
#     fields=None,                 用于展示的字段，列表或者元组：对于GeoJson/TopoJson数据来说，是properties下的标签，GeoDataFrame来说，是列名
#     aliases=None,                字符串的列表或元组，和fields相同长度，用于替代fields中的名称，也即别名
#     labels=True,                 是否展示标签(也即fields和alias)
#     style='margin: auto;',       字符串，HTML内联样式
#     class_name='foliumpopup',
#     localize=True,               是否本地化，True则使用JS中的`.toLocaleString()`来格式化成当地风格
#     **kwargs,
# )
# ```

# %% [markdown]
# ## 6.9 LatLngPopup
# 点击弹出经纬度

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

map.add_child(
    folium.LatLngPopup()
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a95803bd802f01ae293ad6b52efae81a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a95803bd802f01ae293ad6b52efae81a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a95803bd802f01ae293ad6b52efae81a = L.map(
#                 &quot;map_a95803bd802f01ae293ad6b52efae81a&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a95803bd802f01ae293ad6b52efae81a);
#
#
#
#
#
#             var tile_layer_34fb37349edf2611efa32d07d34c6541 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a95803bd802f01ae293ad6b52efae81a);
#
#
#                 var lat_lng_popup_ce7e06e51f9e25f84f195581944d0c91 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_ce7e06e51f9e25f84f195581944d0c91
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_a95803bd802f01ae293ad6b52efae81a);
#                     }
#                 map_a95803bd802f01ae293ad6b52efae81a.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6.10 RegularPolygonMarker
# 根据给定中心绘制正多边形

# %% [markdown]
# ```python
# folium.RegularPolygonMarker(
#     location,             [lat, lng] 中心点
#     number_of_sides=4,    多边形边数
#     rotation=0,           旋转
#     radius=15,            半径
#     popup=None,
#     tooltip=None,
#     **kwargs,
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

# map.add_child(
#     folium.Marker(
#         location=[30.6547, 104.0809],
#     )
# )

map.add_child(
    folium.RegularPolygonMarker(
        location=[30.6547, 104.0809],
        number_of_sides=5,
        radius=200,
        rotation=0,
        weight=20,
        color='darkgreen',
        opacity=0.5
    )
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f65fadec5a6a99c2cbba7f348d6028e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f65fadec5a6a99c2cbba7f348d6028e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f65fadec5a6a99c2cbba7f348d6028e = L.map(
#                 &quot;map_5f65fadec5a6a99c2cbba7f348d6028e&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5f65fadec5a6a99c2cbba7f348d6028e);
#
#
#
#
#
#             var tile_layer_00b910a5cc2b91649e1ee74365d733f6 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f65fadec5a6a99c2cbba7f348d6028e);
#
#
#             var regular_polygon_marker_538bd8c25d33692eb611457fede4ee28 = new L.RegularPolygonMarker(
#                 [30.6547, 104.0809],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 5, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 200, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 20}
#             ).addTo(map_5f65fadec5a6a99c2cbba7f348d6028e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6.11 TopoJson

# %% [markdown]
# ## 6.12 Vega
# 创建一个Vega图表元素
# [Vega](https://vega.github.io/vega/|)诞生于美国华盛顿大学交互数据实验室(Interactive Data Lab)
# vincent包是Python中操作Vega的工具

# %% [markdown]
# ```python
# folium.Vega(
#     data,                 json格式的字符串或者带有to_json方法的对象
#                                 - Vega采用json来描述可视化组件
#     width=None,           整数或者字符串，字符串可以是'px'或'%'
#     height=None,          整数或者字符串，字符串可以是'px'或'%'
#     left='0%',            与父HTML组件左边的距离，整数或者字符串，字符串可以是'px'或'%'
#     top='0%',             与父HTML组件顶边的距离，整数或者字符串，字符串可以是'px'或'%'
#     position='relative',  css包含的position参数值， 如relative absolute
# )
# ```

# %%
data = [10, 20, 30, 40, 50]

vincent.core.initialize_notebook()

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

p = folium.Popup()

folium.Vega(
    vincent.Bar(data, height=300, width=600), height=350, width=650
).add_to(p)

folium.Marker(
    location=[30.6555, 104.0507],
    popup=p,
    max_width='100%'
).add_to(map)

map
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cc93ade7d1ddaa2c1d6e03795aef63c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_20aa657ee95b64f8646e7cca16290031 {
#                 position : relative;
#                 width : 650.0px;
#                 height: 350.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cc93ade7d1ddaa2c1d6e03795aef63c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cc93ade7d1ddaa2c1d6e03795aef63c = L.map(
#                 &quot;map_1cc93ade7d1ddaa2c1d6e03795aef63c&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1cc93ade7d1ddaa2c1d6e03795aef63c);
#
#
#
#
#
#             var tile_layer_6ec50e73c4c6471b738f486ced685007 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1cc93ade7d1ddaa2c1d6e03795aef63c);
#
#
#             var marker_9eb0d83ef6c8d2d210f5c5b711e8695c = L.marker(
#                 [30.6555, 104.0507],
#                 {&quot;maxWidth&quot;: &quot;100%&quot;}
#             ).addTo(map_1cc93ade7d1ddaa2c1d6e03795aef63c);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_2b455ad3d58152394cb302565be7f029 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var vega_20aa657ee95b64f8646e7cca16290031 = $(`             &lt;div id=&quot;vega_20aa657ee95b64f8646e7cca16290031&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_2b455ad3d58152394cb302565be7f029.setContent(vega_20aa657ee95b64f8646e7cca16290031);
#
#
#
#         marker_9eb0d83ef6c8d2d210f5c5b711e8695c.bindPopup(popup_2b455ad3d58152394cb302565be7f029)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;data&quot;, &quot;idx&quot;: 0, &quot;val&quot;: 10}, {&quot;col&quot;: &quot;data&quot;, &quot;idx&quot;: 1, &quot;val&quot;: 20}, {&quot;col&quot;: &quot;data&quot;, &quot;idx&quot;: 2, &quot;val&quot;: 30}, {&quot;col&quot;: &quot;data&quot;, &quot;idx&quot;: 3, &quot;val&quot;: 40}, {&quot;col&quot;: &quot;data&quot;, &quot;idx&quot;: 4, &quot;val&quot;: 50}]}, {&quot;name&quot;: &quot;stats&quot;, &quot;source&quot;: &quot;table&quot;, &quot;transform&quot;: [{&quot;keys&quot;: [&quot;data.idx&quot;], &quot;type&quot;: &quot;facet&quot;}, {&quot;type&quot;: &quot;stats&quot;, &quot;value&quot;: &quot;data.val&quot;}]}], &quot;height&quot;: 300, &quot;legends&quot;: [], &quot;marks&quot;: [{&quot;from&quot;: {&quot;data&quot;: &quot;table&quot;, &quot;transform&quot;: [{&quot;keys&quot;: [&quot;data.col&quot;], &quot;type&quot;: &quot;facet&quot;}, {&quot;height&quot;: &quot;data.val&quot;, &quot;point&quot;: &quot;data.idx&quot;, &quot;type&quot;: &quot;stack&quot;}]}, &quot;marks&quot;: [{&quot;properties&quot;: {&quot;enter&quot;: {&quot;fill&quot;: {&quot;field&quot;: &quot;data.col&quot;, &quot;scale&quot;: &quot;color&quot;}, &quot;width&quot;: {&quot;band&quot;: true, &quot;offset&quot;: -1, &quot;scale&quot;: &quot;x&quot;}, &quot;x&quot;: {&quot;field&quot;: &quot;data.idx&quot;, &quot;scale&quot;: &quot;x&quot;}, &quot;y&quot;: {&quot;field&quot;: &quot;y&quot;, &quot;scale&quot;: &quot;y&quot;}, &quot;y2&quot;: {&quot;field&quot;: &quot;y2&quot;, &quot;scale&quot;: &quot;y&quot;}}}, &quot;type&quot;: &quot;rect&quot;}], &quot;type&quot;: &quot;group&quot;}], &quot;padding&quot;: &quot;auto&quot;, &quot;scales&quot;: [{&quot;domain&quot;: {&quot;data&quot;: &quot;table&quot;, &quot;field&quot;: &quot;data.idx&quot;}, &quot;name&quot;: &quot;x&quot;, &quot;range&quot;: &quot;width&quot;, &quot;type&quot;: &quot;ordinal&quot;, &quot;zero&quot;: false}, {&quot;domain&quot;: {&quot;data&quot;: &quot;stats&quot;, &quot;field&quot;: &quot;sum&quot;}, &quot;name&quot;: &quot;y&quot;, &quot;nice&quot;: true, &quot;range&quot;: &quot;height&quot;}, {&quot;domain&quot;: {&quot;data&quot;: &quot;table&quot;, &quot;field&quot;: &quot;data.col&quot;}, &quot;name&quot;: &quot;color&quot;, &quot;range&quot;: &quot;category20&quot;, &quot;type&quot;: &quot;ordinal&quot;}], &quot;width&quot;: 600},vega_20aa657ee95b64f8646e7cca16290031);
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen

# %%
b = vincent.Bar(data)
b
# Out:
# <div id="vis96a213b4f3844a6fbe466a2207d2d233"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "type": "x"}, {"scale": "y", "type": "y"}], "data": [{"name": "table", "values": [{"col": "data", "idx": 0, "val": 10}, {"col": "data", "idx": 1, "val": 20}, {"col": "data", "idx": 2, "val": 30}, {"col": "data", "idx": 3, "val": 40}, {"col": "data", "idx": 4, "val": 50}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis96a213b4f3844a6fbe466a2207d2d233"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %% [markdown]
# ## 6.13 VegaLite
# 创建一个Vega-Lite图表元素
# [Vega-Lite](https://vega.github.io/vega-lite/)诞生于美国华盛顿大学交互数据实验室(Interactive Data Lab)
# Altair包是Python中操作VegaLite的工具

# %% [markdown]
# ```python
# folium.Vega(
#     data,                 json格式的字符串或者带有to_json方法的对象
#                                 - Vega采用json来描述可视化组件
#     width=None,           整数或者字符串，字符串可以是'px'或'%'
#     height=None,          整数或者字符串，字符串可以是'px'或'%'
#     left='0%',            与父HTML组件左边的距离，整数或者字符串，字符串可以是'px'或'%'
#     top='0%',             与父HTML组件顶边的距离，整数或者字符串，字符串可以是'px'或'%'
#     position='relative',  css包含的position参数值， 如relative absolute
# )
# ```

# %%
source = pd.DataFrame({
    'a': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'],
    'b': [28, 55, 43, 91, 81, 53, 19, 87, 52]
})

c = altair.Chart(source, width=600, height=300).mark_bar().encode(
    x='a',
    y='b'
)



map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

p = folium.Popup()

folium.VegaLite(
    c, height=350, width=650
).add_to(p)

folium.Marker(
    location=[30.6555, 104.0507],
    popup=p,
    max_width='100%'
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e906c0d15806be3cd5ed8e84bfe3177 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_31cab5dde18c2c9d1a0804fc5b9bfb61 {
#                 position : relative;
#                 width : 650.0px;
#                 height: 350.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega@3&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@2&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@3&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e906c0d15806be3cd5ed8e84bfe3177&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e906c0d15806be3cd5ed8e84bfe3177 = L.map(
#                 &quot;map_7e906c0d15806be3cd5ed8e84bfe3177&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7e906c0d15806be3cd5ed8e84bfe3177);
#
#
#
#
#
#             var tile_layer_bb8f667f5cec640f16a2909a0a8b1fa8 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e906c0d15806be3cd5ed8e84bfe3177);
#
#
#             var marker_591bd4863ed18725dc99cc3866dfc741 = L.marker(
#                 [30.6555, 104.0507],
#                 {&quot;maxWidth&quot;: &quot;100%&quot;}
#             ).addTo(map_7e906c0d15806be3cd5ed8e84bfe3177);
#
#
#         var popup_5c452f46162b2d066d1a36cebf6dbba4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var vega_lite_31cab5dde18c2c9d1a0804fc5b9bfb61 = $(`             &lt;div id=&quot;vega_lite_31cab5dde18c2c9d1a0804fc5b9bfb61&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_5c452f46162b2d066d1a36cebf6dbba4.setContent(vega_lite_31cab5dde18c2c9d1a0804fc5b9bfb61);
#
#
#
#         marker_591bd4863ed18725dc99cc3866dfc741.bindPopup(popup_5c452f46162b2d066d1a36cebf6dbba4)
#         ;
#
#
#
#                     vegaEmbed(vega_lite_31cab5dde18c2c9d1a0804fc5b9bfb61, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v4.17.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 400}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-c2a3e89ba9d5d1687d5e8c28d630a033&quot;}, &quot;datasets&quot;: {&quot;data-c2a3e89ba9d5d1687d5e8c28d630a033&quot;: [{&quot;a&quot;: &quot;A&quot;, &quot;b&quot;: 28}, {&quot;a&quot;: &quot;B&quot;, &quot;b&quot;: 55}, {&quot;a&quot;: &quot;C&quot;, &quot;b&quot;: 43}, {&quot;a&quot;: &quot;D&quot;, &quot;b&quot;: 91}, {&quot;a&quot;: &quot;E&quot;, &quot;b&quot;: 81}, {&quot;a&quot;: &quot;F&quot;, &quot;b&quot;: 53}, {&quot;a&quot;: &quot;G&quot;, &quot;b&quot;: 19}, {&quot;a&quot;: &quot;H&quot;, &quot;b&quot;: 87}, {&quot;a&quot;: &quot;I&quot;, &quot;b&quot;: 52}]}, &quot;encoding&quot;: {&quot;x&quot;: {&quot;field&quot;: &quot;a&quot;, &quot;type&quot;: &quot;nominal&quot;}, &quot;y&quot;: {&quot;field&quot;: &quot;b&quot;, &quot;type&quot;: &quot;quantitative&quot;}}, &quot;height&quot;: 300, &quot;mark&quot;: &quot;bar&quot;, &quot;width&quot;: 600})
#                         .then(function(result) {})
#                         .catch(console.error);
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
altair.Chart?
# Out:
# Init signature:
# altair.Chart(
#     data=Undefined,
#     encoding=Undefined,
#     mark=Undefined,
#     width=Undefined,
#     height=Undefined,
#     **kwargs,
# )
# Docstring:
# Create a basic Altair/Vega-Lite chart.
#
# Although it is possible to set all Chart properties as constructor attributes,
# it is more idiomatic to use methods such as ``mark_point()``, ``encode()``,
# ``transform_filter()``, ``properties()``, etc. See Altair's documentation
# for details and examples: http://altair-viz.github.io/.
#
# Attributes
# ----------
# data : Data
#     An object describing the data source
# mark : AnyMark
#     A string describing the mark type (one of `"bar"`, `"circle"`, `"square"`, `"tick"`,
#      `"line"`, * `"area"`, `"point"`, `"rule"`, `"geoshape"`, and `"text"`) or a
#      MarkDef object.
# encoding : FacetedEncoding
#     A key-value mapping between encoding channels and definition of fields.
# autosize : anyOf(AutosizeType, AutoSizeParams)
#     Sets how the visualization size should be determined. If a string, should be one of
#     `"pad"`, `"fit"` or `"none"`. Object values can additionally specify parameters for
#     content sizing and automatic resizing. `"fit"` is only supported for single and
#     layered views that don't use `rangeStep`.  __Default value__: `pad`
# background : string
#     CSS color property to use as the background of visualization.
#
#     **Default value:** none (transparent)
# config : Config
#     Vega-Lite configuration object.  This property can only be defined at the top-level
#     of a specification.
# description : string
#     Description of this mark for commenting purpose.
# height : float
#     The height of a visualization.
# name : string
#     Name of the visualization for later reference.
# padding : Padding
#     The default visualization padding, in pixels, from the edge of the visualization
#     canvas to the data rectangle.  If a number, specifies padding for all sides. If an
#     object, the value should have the format `{"left": 5, "top": 5, "right": 5,
#     "bottom": 5}` to specify padding for each side of the visualization.  __Default
#     value__: `5`
# projection : Projection
#     An object defining properties of geographic projection.  Works with `"geoshape"`
#     marks and `"point"` or `"line"` marks that have a channel (one or more of `"X"`,
#     `"X2"`, `"Y"`, `"Y2"`) with type `"latitude"`, or `"longitude"`.
# selection : Mapping(required=[])
#     A key-value mapping between selection names and definitions.
# title : anyOf(string, TitleParams)
#     Title for the plot.
# transform : List(Transform)
#     An array of data transformations such as filter and new field calculation.
# width : float
#     The width of a visualization.
# File:           d:\programs\anaconda3\lib\site-packages\altair\vegalite\v4\api.py
# Type:           type
# Subclasses:

# %% [markdown]
# # 7. 插件类

# %% [markdown]
# ## 7.1 AntPath
# 动态路径，显示从开始到结尾的动画

# %% [markdown]
# ```python
# plugins.AntPath(
#     locations,    [lat, lng]列表
#     popup=None,
#     tooltip=None,
#     **kwargs     https://github.com/rubenspgcavalcante/leaflet-ant-path/
# )
# ```

# %%
pts = [[30.6555, 104.0507], [30.6547, 104.0809], [30.6422, 104.1003], [30.6178, 104.0922], [30.6098, 104.0424]]

map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

map.add_child(
    plugins.AntPath(
        locations=pts,
        color='red',
    )
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b7a134ee9f1ee26cff0c04b5de2077f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b7a134ee9f1ee26cff0c04b5de2077f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b7a134ee9f1ee26cff0c04b5de2077f = L.map(
#                 &quot;map_8b7a134ee9f1ee26cff0c04b5de2077f&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8b7a134ee9f1ee26cff0c04b5de2077f);
#
#
#
#
#
#             var tile_layer_21b0db3a9108dcfe7be07cfc62a6161c = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b7a134ee9f1ee26cff0c04b5de2077f);
#
#
#             ant_path_47d326cd40380ade1b3f84436e6cadc0 = L.polyline.antPath(
#               [[30.6555, 104.0507], [30.6547, 104.0809], [30.6422, 104.1003], [30.6178, 104.0922], [30.6098, 104.0424]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_8b7a134ee9f1ee26cff0c04b5de2077f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.2 BeautifyIcon
# 使用数字，或者font-awesome图标，进行颜色等设置

# %% [markdown]
# ```python
# plugins.BeautifyIcon(
#     icon=None,               font-awesome图标
#     icon_shape=None,         图标形状，可选为：circle, marker, circle-dot, rectangle, rectangle-dot, doughnut
#     border_width=3,          整数，图标边缘宽度
#     border_color='#000',     图标边缘颜色
#     text_color='#000',       字符颜色
#     background_color='#FFF', 背景颜色
#     inner_icon_style='',     css格式字符串
#     spin=False,              旋转
#     number=None,             图标的数字
#     **kwargs,
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

folium.Marker(
    location=[30.6555, 104.0507],
    icon=plugins.BeautifyIcon(
        number=10,
        text_color='darkgreen',
        spin=True,
        border_color='red',
        border_width=3,
        icon_shape='marker'
    )
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3dc16053e5873b1c8da2a377250e26d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3dc16053e5873b1c8da2a377250e26d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3dc16053e5873b1c8da2a377250e26d = L.map(
#                 &quot;map_e3dc16053e5873b1c8da2a377250e26d&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e3dc16053e5873b1c8da2a377250e26d);
#
#
#
#
#
#             var tile_layer_e1a28870da3fdd7c941e11bbcf7e9ee1 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3dc16053e5873b1c8da2a377250e26d);
#
#
#             var marker_4247c9be0efd880fe13b1b59dc4f0336 = L.marker(
#                 [30.6555, 104.0507],
#                 {}
#             ).addTo(map_e3dc16053e5873b1c8da2a377250e26d);
#
#
#             var beautify_icon_a0b6749ba2f0e2e23db4cdfaa1cdadce = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;red&quot;, &quot;borderWidth&quot;: 3, &quot;iconShape&quot;: &quot;marker&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: true, &quot;text&quot;: 10, &quot;textColor&quot;: &quot;darkgreen&quot;}
#             )
#             marker_4247c9be0efd880fe13b1b59dc4f0336.setIcon(beautify_icon_a0b6749ba2f0e2e23db4cdfaa1cdadce);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.3 BoatMarker
# 绘制船型图和风向图

# %% [markdown]
# ```python
# plugins.BoatMarker(
#     location,              船型标志的位置，默认是None，此时在地图中心
#     popup=None,
#     icon=None,
#     heading=0,             船头指向的角度，[0,360]
#     wind_heading=None,     风向标志的角度，[0, 360]，如果为None表示不展示风向图标
#     wind_speed=0,          风速，整数，单位为节
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)
plugins.BoatMarker(
    location=[30.6555, 104.0507],
    heading=90,
    wind_heading=45,
    wind_speed=30,
    color='royalblue'
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df86628468db0f2d2a64bc0851643d1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.boatmarker/leaflet.boatmarker.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df86628468db0f2d2a64bc0851643d1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df86628468db0f2d2a64bc0851643d1b = L.map(
#                 &quot;map_df86628468db0f2d2a64bc0851643d1b&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_df86628468db0f2d2a64bc0851643d1b);
#
#
#
#
#
#             var tile_layer_c752026f27cfcd64284d50073b82e01a = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df86628468db0f2d2a64bc0851643d1b);
#
#
#             var boat_marker_64f40c8b42fb4e3eeafb84df2b6d5072 = L.boatMarker(
#                 [30.6555, 104.0507],
#                 {&quot;color&quot;: &quot;royalblue&quot;}
#             ).addTo(map_df86628468db0f2d2a64bc0851643d1b);
#             boat_marker_64f40c8b42fb4e3eeafb84df2b6d5072.setHeadingWind(
#                 90,
#                 30,
#                 45
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.4 Draw
# 在地图上添加绘制线面等的工具

# %% [markdown]
# ```python
# plugins.Draw(
#     export=False,            导出按钮，默认False，True表示会添加一个小按钮，将绘制的区域导出为geojson文件，位置在右侧
#     filename='data.geojson', 导出的文件名
#     position='topleft',      工具栏的位置，默认为左上角
#     draw_options=None,       工具栏设置，字典类型，http://leaflet.github.io/Leaflet.draw/docs/leaflet-draw-latest.html#drawoptions
#     edit_options=None,       编辑栏设置，字典类型，https://leaflet.github.io/Leaflet.draw/docs/leaflet-draw-latest.html#editpolyoptions
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

plugins.Draw(
    export=True,
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9955fe69be2ef64ca7b390afcec68d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9955fe69be2ef64ca7b390afcec68d5&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9955fe69be2ef64ca7b390afcec68d5 = L.map(
#                 &quot;map_c9955fe69be2ef64ca7b390afcec68d5&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c9955fe69be2ef64ca7b390afcec68d5);
#
#
#
#
#
#             var tile_layer_b83db3076d93d837136d38c2824dc89e = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9955fe69be2ef64ca7b390afcec68d5);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_c9955fe69be2ef64ca7b390afcec68d5
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_18d7c5a5669e4a2220d5088667f56db8 = new L.Control.Draw(
#                 options
#             ).addTo( map_c9955fe69be2ef64ca7b390afcec68d5 );
#             map_c9955fe69be2ef64ca7b390afcec68d5.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_c9955fe69be2ef64ca7b390afcec68d5.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#             document.getElementById(&#x27;export&#x27;).onclick = function(e) {
#                 var data = drawnItems.toGeoJSON();
#                 var convertedData = &#x27;text/json;charset=utf-8,&#x27;
#                     + encodeURIComponent(JSON.stringify(data));
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;href&#x27;, &#x27;data:&#x27; + convertedData
#                 );
#                 document.getElementById(&#x27;export&#x27;).setAttribute(
#                     &#x27;download&#x27;, &quot;data.geojson&quot;
#                 );
#             }
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.5 DualMap
# 绘制并列地图，可以对地图做不同操作
# - 属性：
#     - m1: 第一幅地图
#     - m2: 第二幅地图
# - 定义：
#     - 直接使用`DualMap`中的tiles指定瓦片，则此时两幅地图是一样的
#     - 先定义一个`DualMap`对象，再分别定义不同瓦片的`TileLayer`对象，随后将两个`Map`对象添加到`m1`，`m2`属性中

# %% [markdown]
# ```python
# plugins.DualMap(
#     location=None,         地图视角中心
#     layout='horizontal',   地图并列方式
#     **kwargs
# )
# ```

# %%
dual_map = plugins.DualMap(location=[30.6587, 104.0658], tiles=None)

m1 = folium.TileLayer(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图'
)
m1.add_to(dual_map.m1)

m2 = folium.TileLayer(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=6&ltype=6',
    attr='高德-卫星图'
)
m2.add_to(dual_map.m2)

folium.Marker(
    location=[30.6555, 104.0507],
).add_to(dual_map)

dual_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_003c78691ddaef25b0de53b0e98c4b96 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a14b867f38abb548b721556ad72893e3 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 50.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/jieter/Leaflet.Sync/L.Map.Sync.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_003c78691ddaef25b0de53b0e98c4b96&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a14b867f38abb548b721556ad72893e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_003c78691ddaef25b0de53b0e98c4b96 = L.map(
#                 &quot;map_003c78691ddaef25b0de53b0e98c4b96&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e35b9dccdecc8b4cd050bf0814257df = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_003c78691ddaef25b0de53b0e98c4b96);
#
#
#             var marker_370485bfa6b48f1964af71a81d8c7dcb = L.marker(
#                 [30.6555, 104.0507],
#                 {}
#             ).addTo(map_003c78691ddaef25b0de53b0e98c4b96);
#
#
#             var map_a14b867f38abb548b721556ad72893e3 = L.map(
#                 &quot;map_a14b867f38abb548b721556ad72893e3&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4895413cc52f0fcf744928b7e131935 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=6\u0026ltype=6&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u536b\u661f\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a14b867f38abb548b721556ad72893e3);
#
#
#             map_003c78691ddaef25b0de53b0e98c4b96.sync(map_a14b867f38abb548b721556ad72893e3);
#             map_a14b867f38abb548b721556ad72893e3.sync(map_003c78691ddaef25b0de53b0e98c4b96);
#
#
#             var marker_50f0dc92280d4f30abf4ce9fe6c4430d = L.marker(
#                 [30.6555, 104.0507],
#                 {}
#             ).addTo(map_a14b867f38abb548b721556ad72893e3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.6 FastMarkerCluster
# 用于快速将上千个点标记在地图上，且地图缩放后，点会聚集为一个带有数字的标记
# 但是功能比较少，速度较`plugins.MarkerCluster`快

# %% [markdown]
# ```python
# plugins.FastMarkerCluster(
#     data,                         [lat, lng]组成的列表，如果callback参数传参了，可以在lat, lng后加其他参数
#     callback=None,                字符串，表示JS函数，能够作用于data内部的子列表
#     options=None,
#     name=None,
#     overlay=True,
#     control=True,
#     show=True,
#     icon_create_function=None,
#     **kwargs,
# )
# ```

# %% [markdown]
# ## 7.7 FloatImage
# 在地图上显示图片

# %% [markdown]
# ```python
# plugins.FloatImage(
#     image,
#     bottom=75,
#     left=75,
#     width=100
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

map.add_child(
    plugins.FloatImage(
        image='https://tse1-mm.cn.bing.net/th/id/OIP-C.MMeRftiQcD77hYa7_ttwtwHaHa?pid=ImgDet&rs=1',
        left=20,
        bottom=20,
        width=10
    )
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_591a0f2734409dca9e6442dde12de67c {
#                         position:absolute;
#                         bottom:20%;
#                         left:20%;
#                         width:10%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_591a0f2734409dca9e6442dde12de67c&quot; alt=&quot;float_image&quot;
#                  src=&quot;https://tse1-mm.cn.bing.net/th/id/OIP-C.MMeRftiQcD77hYa7_ttwtwHaHa?pid=ImgDet&amp;rs=1&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8 = L.map(
#                 &quot;map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8);
#
#
#
#
#
#             var tile_layer_3b84c3025ae57696adecabe1ab01a637 = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6fcfb3c8b9bbe808f5ce1f6324d4d0e8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.8 FullScreen

# %% [markdown]
# ```python
# plugins.Fullscreen(
#     position='topleft',               按钮位置  'topleft', 'topright', 'bottomright' or 'bottomleft'
#     title='Full Screen',              未全屏时按钮的提示文本
#     title_cancel='Exit Full Screen',  全屏时按钮的提示文本
#     force_separate_button=False,      是否和放大缩小按钮分开，默认False，表示在一起
# )
# ```

# %%
map = folium.Map(
    tiles= 'https://wprd02.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7&ltype=7',
    attr='高德-常规图',
    location=[30.6587, 104.0658],
    min_zoom=9, 
    zoom_start=13,
    control_scale=True,
)

map.add_child(
    plugins.Fullscreen(
        position='topright',
        force_separate_button=True
    )
)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79f5e728639d8c0f7e736d4662857e87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79f5e728639d8c0f7e736d4662857e87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79f5e728639d8c0f7e736d4662857e87 = L.map(
#                 &quot;map_79f5e728639d8c0f7e736d4662857e87&quot;,
#                 {
#                     center: [30.6587, 104.0658],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_79f5e728639d8c0f7e736d4662857e87);
#
#
#
#
#
#             var tile_layer_2a67bbdf84b72d4f5998a29a6a0404ac = L.tileLayer(
#                 &quot;https://wprd02.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7\u0026ltype=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_79f5e728639d8c0f7e736d4662857e87);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: true, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_79f5e728639d8c0f7e736d4662857e87);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7.9 GeoCoder

# %% [markdown]
# ## 7.10 HeatMap

# %% [markdown]
# ## 7.11 HeatMapWithTime

# %% [markdown]
# ## 7.12 LocateControl

# %% [markdown]
# ## 7.13 MarkerCluster
# 批量在地图上添加标记

# %% [markdown]
# ```python
# plugins.MarkerCluster(
#     locations=None,
#     popups=None,
#     icons=None,
#     name=None,
#     overlay=True,
#     control=True,
#     show=True,
#     icon_create_function=None,
#     options=None,
#     **kwargs,
# )
# ```

# %% [markdown]
# ## 7.14 MeasureControl

# %% [markdown]
# ## 7.15 MiniMap

# %% [markdown]
# ## 7.16 MousePosition

# %% [markdown]
# ## 7.17 ScrollZoomToggler

# %% [markdown]
# ## 7.18 Search

# %% [markdown]
# ## 7.19 SemeCircle

# %% [markdown]
# ## 7.20 Terminator
